# %% [markdown]
# ### Glint Summary Statistics and Analysis Script

# %%
import numpy as np
import pandas as pd
import glob as glob
import statsmodels.api as sm
from statsmodels.formula.api import ols

#Define the path to the CSV file containing the summary data and the experiment version
base_path = "/zpool/vladlab/data_drive/glint_data/summary_data_csv" #Folder containing all the summary data CSV files

experiment_version = "familiar" #Experiment version to analyze (e.g., "familiar", "novel")

extreme_version = True #Whether to analyze the extreme version of the experiment (True or False)

#Take the user inserted parameters and define the variables extreme and experiment
experiment = experiment_version # Set the experiment variable to match user input

#Determine the extreme version based on user input
if extreme_version == True:
    extreme = "extreme"
elif extreme_version == False:
    extreme = "original"

#Construct the full path to the specific CSV file based on the experiment and extreme version
data_path = f"{base_path}/{experiment}_glint_{extreme}_cleaned_wide.csv" #Construct the path to the specific CSV file based on user input

#Load the data from the specified CSV file into a pandas DataFrame
data = pd.read_csv(data_path) #Load the data from the specified CSV file

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
