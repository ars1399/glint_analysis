# %% [markdown]
# # Glint Data Processing Master Script
#
# In this script each of the four versions of the glint experiment are able to be processed into a master data sheet for each experiment.
#
# The experiments include:
# (1) Original Familiar Glint
# (2) Original Novel Glint
# In both of these experiments, three conditions of transformed images are presented with only one stimulus duration.
#
# The second set of experiments include:
# (3) Familiar Glint Extreme
# (4) Novel Glint Extreme
# In these two versions, three conditions of transformed images are presented with 4 different stimulus durations.
#
# The distinction between familiar and novel is that familiar shows participants previously learned images, while novel presents unknown images that are learned and then tested on.
#
# The functions are split into two cells for the notebook for visualisation purposes, but for actual python script, they will grouped together at start of script.
#
# I highly recommend always resetting the variables before each version.

# %%
#Clear previous output and variables to ensure no mixing of the data
# %reset -f

# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb

# %% [markdown]
# ## Preprocessing and Exclusion Functions

# %%
def preprocessing_pipeline(experiment_type, is_extreme, mini):
    """Preprocess GLINT data based on experiment type and extreme flag.
    1. Sets experiment parameters.
    2. Loads data files.
    3. Loops through subjects, conditions, stimulus duration, and animacy to filter trials and calculate accuracy.
    4. Compiles results into a summary dataframe.
    
    Inputs: 
        experiment_type (str): 'novel' or 'familiar' to specify experiment version.
        is_extreme (bool): True for extreme version, False for original version.
        mini (bool): True for mini version, False for full version.
    Returns:
        sub_summary (pd.DataFrame): Summary dataframe with accuracy and trial counts.
        settings (dict): Configuration dictionary with experiment parameters.
        experiment (str): Experiment version used.
        extreme (bool): Extreme flag used.
    """

    ''' Experiment parameters and settings (1 & 2 are inputs, 3-7 defined by the inputs or hard coded)
    1. experiment (novel or familiar)
    2. extreme flag (True for extreme version, False for original version)
    3. durations (if extreme is True) 
    4. animacies 
    5. base path for data
    6. file paths for the selected experiment version
    7. base columns for summary dataframe
    '''
    settings = {'experiment': experiment_type,'extreme': is_extreme, 'mini': mini}
    
    experiment = settings['experiment'] #version of the experiment: familiar or novel

    extreme = settings['extreme'] # Sets extreme flag to determine if this is the extreme version of the experiment or not

    mini = settings['mini'] # Sets mini flag to determine if this is the mini version of the experiment or not

    if extreme == True:
        durations = [0.3, 0.136, 0.068, 0.034] if extreme == True else [None] #durations only matter if extreme is True
    elif extreme == False:
        durations = [0.3] #if not extreme, duration is not applicable

    if experiment == 'familiar':
        animacies = ['anim_natural', 'inanim_natural', 'inanim_artificial']
    
    elif experiment == 'novel':
        animacies = ['inanim_artificial'] #animacies for both versions of the experiment, but we define them here for clarity and consistency in the code structure


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                #'un_filtered_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'no_responses', #number of no responses
                'num_trials_after_exclusion', #number of trials after all exclusions
                'num_of_outliers', #number of RT outliers
                'num_of_fast_responses', #number of fast responses (RT < 100ms)
                'total_number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses + RT outliers)
    
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data


    #Need to differentiate the file paths based on if this is extreme or not
    base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
    
    if mini == True:
        core_path = f'{base}/mini_glint' # set core path for mini version using experiment variable and base path
        print(f' You have selected Mini-Glint experiment')
    elif mini == False: 
        print(f' You have selected the full version of the experiment, specifically:')
        if extreme == True:
            core_path = f'{base}/{experiment}_glint_extreme' # set core path using experiment variable and base path
            print(f"You have selected {experiment} glint extreme experiment")

        elif extreme == False: 
            core_path = f'{base}/{experiment}_glint' # set core path using experiment variable and base path
            print(f"You have selected {experiment} glint experiment")
        
    


    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        except Exception as e:
            print(f"Failed to read {file}: {e}")

            raise ValueError("No file by this name.")
        
    
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")

            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class",}

        #rename the colimns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # Loop through each condition
        if mini == True:
            conditions_to_process = ['feature', 'shape']
        else:
            conditions_to_process = ['natural', 'feature', 'shape']

        for condition in conditions_to_process:            
            # Check for required columns
            needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition',]  #list of needed columns for processing
            if extreme == True:
                needed.append('stimulus_duration') #if extreme is True, we also need the stimulus duration column for processing
            
            # Tells you exactly which columns are present or missing allowing for quick diagnosis of any issues with the data files.
            print(f"\n  Available columns: {data.columns.tolist()}")
            print(f"  Required columns: {needed}")
            missing_cols = [col for col in needed if col not in data.columns]
            if missing_cols:
                print(f"  MISSING: {missing_cols}")

            if mini == True and 'stimulus_duration' not in data.columns:
                print(f"  Adding missing 'stimulus_duration' column for mini version")
                data['stimulus_duration'] = 0.3  # Set default value
                missing_cols = [col for col in missing_cols if col != 'stimulus_duration']

            if any(col not in data.columns for col in needed): 
                print(f"Missing expected columns in {file}") 
                raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
            
            
            # Loop through stimulus durations and animacies if applicable
            for stimulus_duration in durations: 
                
                # Nested loop for animacy if applicable
                for animacy in animacies: #loop through each animacy
                    

                    # Use trials function to import trials and filter based on current parameters
                    if mini == True:
                        trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]
                    elif mini == False:
                        if extreme == False:
                            trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)] #if not extreme, we don't need to filter by stimulus duration, so we only filter by condition and animacy
                        
                        elif extreme == True:
                            trials = data[(data['condition'] == condition) & (data['stimulus_duration'] == stimulus_duration) & (data['animacy'] == animacy)]
                        
                    # Check if trials is None or empty, and will raise an error if so
                    if mini == False:
                        if trials is None or len(trials) == 0:
                            print(f"  No trials found for {condition}, {animacy}, {stimulus_duration}")
                            raise ValueError("No trials found.")
                    if mini == True:
                        if trials is None or len(trials) == 0:
                            print(f"  Skipping {condition} - no trials found for {animacy}, {stimulus_duration}")
                            continue  # Gracefully skip instead of erroring
                        
                    # Takes only trials with a response, and counts the number of no responses
                    no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
                    number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses


                    '''
                    Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
                    Exclusion Criteria 2: RTs outside mean ± 2*SD
                    We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
                    and then we apply the RT filters to those trials. This way we can accurately count 
                    the number of no responses, fast responses, and RT outliers separately.
                    '''

                    #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
                    rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
                    number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms
    

                    #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
                    rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
                    mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
                    std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT



                    #Filters out RTs outside mean ± 2*SD, and counts the number of RT outliers
                    if len(rt_plus_minus_2sd) < 2 or pd.isna(std_rt): #if there are less than 2 trials with RTs greater than 100ms, we cannot calculate a standard deviation, so we will skip this step and not filter out any RTs based on the mean ± 2*SD criterion
                        final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion
                    
                    else:
                        final_trials = rt_less_equal_100[rt_less_equal_100['key_resp.rt'].between(mean_rt - 2*std_rt, mean_rt + 2*std_rt)] #filter out RTs outside mean ± 2*SD

                    number_of_outliers = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers
                        

                    # Calculate the variables of interest and compile into a row for condition summary
                    #acc = trials['key_resp.corr'].mean() #accuracy before filtering (removed from final code as it is meant for debugging)
                    filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   
                    trial_count = len(final_trials) #number of trials after all exclusions


                    #Combines the experiment and extreme parameters into a single label for the summary dataframe
                    extreme_label = 'extreme' if extreme else 'original' #create label for extreme status

                    experiment_label = f"{experiment}_{extreme_label}"  #combine experiment and extreme status into a single label for the summary dataframe    

                    #sums up the total number of trials for this condition, stimulus duration, and animacy that were excluded based on the filters applied
                    number_of_excluded_trials = number_of_no_responses + number_of_fast_responses + number_of_outliers 

                    #Compiles all the variables of interest into a row for the condition summary dataframe
                    row = {
                        'experiment_label': experiment_label, #experiment and extreme status
                        'id': sub, #subject identifier
                        'condition': condition, #condition (natural, scrambled, line_drawing)
                        'stimulus_duration': stimulus_duration, #stimulus duration (only if extreme is True)
                        'animacy': animacy, #animacy (only if animacy_inclusion is True)
                        #'un_filtered_acc': acc, #accuracy before filtering
                        'filtered_acc': filtered_acc, #accuracy after filtering
                        'practice_acc': practice_trials, #accuracy in practice trials
                        'no_responses': number_of_no_responses, #number of no responses
                        'num_trials_after_exclusion': trial_count, #number of trials after all exclusions
                        'num_of_outliers': number_of_outliers, #number of RT outliers
                        'num_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
                        'total_number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
                    }

                    # Add the row to the condition summary
                    condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

        # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, extreme  # return config so downstream steps use the same values


'''
Exclusion Criteria Functions
Here we define the functions needed to do participant exclusion.
Our exclusion criteria are:
1. Participants with accuracy in the natural condition below chance level (calculated based on the number of response options for each experiment version).
2. Participants with accuracy in the natural condition below mean - 2*SD of the natural condition accuracies across all subjects.

Functions:
1. chance_calculator: Calculates the chance level based on the experiment version and extreme flag.
Inputs: experiment version (novel or familiar) and extreme flag (True or False)
Outputs: chance level (float)

2. exclusion_check: Identifies subjects to exclude based on the two criteria and prints the results
Inputs: sub_summary dataframe and chance level
Outputs: DataFrame of flagged subjects for exclusion

3. remove_flagged_subjects: Removes the flagged subjects from the sub_summary dataframe and returns the cleaned dataframe.
Inputs: sub_summary dataframe, flagged subjects dataframe, delete flag (True to remove, False to keep for review)
Outputs: cleaned sub_summary dataframe after removing flagged subjects (if delete=True), otherwise returns original sub_summary for review.

4. create_wide_format: Creates a wide-format version of the cleaned dataframe for downstream analyses.
Inputs: cleaned sub_summary dataframe
Outputs: cleaned long-format dataframe, cleaned wide-format dataframe, and saves both to CSV files with appropriate naming based on the experiment version and extreme flag.

5. plot_summary: Quick visualization function to plot the summary data for a quick check of the results after preprocessing.
'''

def chance_calculator(experiment, extreme):
    """Return the number of response options for the given experiment/extreme combo."""
    mapping = {
        ('novel', False): 4,
        ('novel', True): 4,
        ('familiar', True): 6,
        ('familiar', False): 9,
    }

    number_of_choices = mapping.get((experiment, extreme))

    chance = 1 / number_of_choices #formula for calculating chance 
    print(f"Calculated chance level based on {number_of_choices} choices: {chance:.3f}")
    return chance

def exclusion_check(sub_summary,chance):
    """Returns per_sub DataFrame with natural condition accuracies per subject."""
    
    natural_acc = sub_summary[sub_summary['condition'] == 'natural'] # Filters for the condition of natural, and calculates the mean
    
    if natural_acc.empty:
        print("No 'natural' rows found in `sub_summary`.")
        # Return empty DataFrame with expected columns to avoid UnboundLocalError
        raise ValueError("No 'natural' rows found in sub_summary; cannot compute exclusion criteria.")
    
    per_sub = (
        natural_acc.groupby('id', as_index=False)['filtered_acc']
        .mean()
        .rename(columns={'filtered_acc': 'natural_filtered_acc'})
    )

    """Calculate threshold for exclusion based on mean - 2*SD of natural accuracies."""
    mean_nat = per_sub['natural_filtered_acc'].mean() #calculate mean of natural filtered accuracy
    sd_nat = per_sub['natural_filtered_acc'].std(ddof=1) #calculate standard deviation of natural filtered accuracy
    thresh = mean_nat - 2 * sd_nat #calculate threshold as mean - 2*SD
    print(f"Natural condition: mean = {mean_nat:.3f}, sd = {sd_nat:.3f}, threshold (mean - 2sd) = {thresh:.3f}") #print threshold values
    
    ''' Flag subjects below chance level and below 2SD threshold, and print results.'''
    flagged_below_chance = per_sub[per_sub['natural_filtered_acc'] <= chance].copy() #flag subjects below chance level
    
    print(f"Chance threshold = {chance:.3f}") 
    
    print(f"Found {len(flagged_below_chance)} subject(s) below chance:") 
    
    if not flagged_below_chance.empty: 
        
        print(flagged_below_chance.sort_values('natural_filtered_acc')) #print flagged subjects below chance level
    

    flagged = per_sub[per_sub['natural_filtered_acc'] <= thresh].copy() #flag subjects below 2SD threshold
    
    print(f"Threshold for exclusion (mean - 2sd) = {thresh:.3f}")
    
    print(f"Found {len(flagged)} subject(s) below or equal to threshold:")
    
    if not flagged.empty:
        
        print(flagged.sort_values('natural_filtered_acc'))
    
    # Combine with flagged_below_chance if any
    if not flagged_below_chance.empty:
        
        flagged = pd.concat([flagged, flagged_below_chance], ignore_index=True).drop_duplicates()  #combine flagged subjects below chance with those below 2SD threshold
        
        print("Subjects below chance combined with subjects below 2SD threshold.")
    
    if flagged.empty:
        print("No subjects are below (or equal to) mean - 2*SD for natural filtered accuracy.")

    else:
        print(f"Flagged {len(flagged)} subject(s) total for exclusion:")

        print(flagged.sort_values('natural_filtered_acc'))
    
    return flagged 

def remove_flagged_subjects(sub_summary, flagged, delete=True):
    if flagged.empty:

        print("No subjects to remove based on exclusion criteria.")

        return sub_summary.copy() #return original sub_summary if no flagged subjects
    
    flagged_df = flagged.copy() #make a copy of flagged subjects DataFrame

    print(f"Flagged subjects to remove ({len(flagged_df)}):")

    print(flagged_df.sort_values('natural_filtered_acc'))
    
    flagged_subs = set(flagged_df['id']) #get unique subject identifiers from flagged subjects

    n_rows_before = len(sub_summary) #count number of rows before removal

    n_rows_removed = sub_summary['id'].isin(flagged_subs).sum() #count number of rows to be removed
    print(f"Preview: {n_rows_removed} rows (of {n_rows_before}) belong to flagged subject(s).") 
    
    if delete:

        cleaned = sub_summary[~sub_summary['id'].isin(flagged_subs)].copy() #remove flagged subjects from sub_summary
        print(f"Removed {n_rows_removed} rows.")
    else:
        cleaned = sub_summary.copy() #keep original sub_summary if delete is False
        print("Delete=False: Keeping all rows in cleaned dataset.")
    
    return cleaned


def create_wide_df_save(cleaned, experiment, extreme, mini, output_path):
    cleaned_wide = None
    
    #I kept running into errors when trying to create the wide format, so I wrapped it in a try except block to catch any errors and print them out
    try:
        values = ['filtered_acc', 'no_responses', 'num_trials_after_exclusion', 'num_of_outliers', 'num_of_fast_responses', 'total_number_of_excluded_trials'] #values to pivot on
        #values = ['un_filtered_acc', 'filtered_acc', 'no_responses', 'num_trials_after_exclusion', 'num_of_outliers', 'num_of_fast_responses', 'total_number_of_excluded_trials'] #values to pivot on

        pivot_df = cleaned.pivot(index='id', columns=['condition', 'stimulus_duration', 'animacy'], values=values) #pivot table with condition, stimulus_duration, and animacy as columns
        
        new_cols = [] #new column names list


        for col in pivot_df.columns: #loop through the columns in the pivoted dataframe to format the column names

            if len(col) == 3:
                metric, condition, duration = col #unpack the column tuple into metric, condition, and duration

                new_cols.append(f"{condition}_{duration}_{metric}") #format new column names

            else:
                new_cols.append("_".join([str(c) for c in col])) #join other columns as strings

        pivot_df.columns = new_cols #assign new column names to the pivoted dataframe

        pivot_df.reset_index(inplace=True) #reset index to make 'id' a column again

        cleaned_wide = pivot_df #assign pivoted DataFrame to cleaned_wide

        wide_df = cleaned_wide

        natural_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_natural") and c != "filtered_acc_natural_overall"]
        feature_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_feature") and c != "filtered_acc_feature_overall"]
        shape_cols   = [c for c in wide_df.columns if c.startswith("filtered_acc_shape")   and c != "filtered_acc_shape_overall"]

        natural_accuracy = wide_df[natural_cols].sum(axis=1, skipna=True) / len(natural_cols) if natural_cols else np.nan
        feature_accuracy = wide_df[feature_cols].sum(axis=1, skipna=True) / len(feature_cols) if feature_cols else np.nan
        shape_accuracy   = wide_df[shape_cols].sum(axis=1, skipna=True) / len(shape_cols) if shape_cols else np.nan

        wide_df["filtered_acc_natural_overall"] = natural_accuracy
        wide_df["filtered_acc_feature_overall"] = feature_accuracy
        wide_df["filtered_acc_shape_overall"]   = shape_accuracy

        cleaned_wide = wide_df
        
    except Exception as e:

        cleaned_wide = None #assign None to cleaned_wide if there was an error during pivoting

        print(f"Could not create wide-format: {e}") #alerts you if there was an error in pivoting data

    #Create a name for the final csv files based on the experiment version and extreme flag
    version = 'extreme' if extreme else 'original' #determine version based on extreme status

    final_csv = f'{experiment}_glint_{version}_cleaned.csv' #construct final CSV filename

    #Save the cleaned long-format
    cleaned.to_csv(os.path.join(output_path, final_csv), index=False) #save long-format DataFrame to CSV

    print(f"Final cleaned sub_summary saved to {os.path.join(output_path, final_csv)}") 

    # Save the wide-format DataFrame to CSV, if it was successfully created
    if cleaned_wide is not None:

        

        cleaned_wide.to_csv(os.path.join(output_path, f'{experiment}_glint_{version}_cleaned_wide.csv'), index=False) #save wide-format DataFrame to CSV

        print(f"Final cleaned wide-format sub_summary saved to {os.path.join(output_path, f'{experiment}_glint_{version}_cleaned_wide.csv')}")

    return cleaned, cleaned_wide

# Quick Visualization
def plot_summary(data, extreme,chance):
    import seaborn as sns
    import matplotlib.pyplot as plt

    fig, ax1 = plt.subplots(figsize=(8, 5))
    if extreme == False:
        sns.barplot(
            data=data,
            x="condition",
            y="filtered_acc",
            ax = ax1,
            capsize=0.3,
            errorbar=("ci", 95),
            palette="magma",
            zorder=2,
            hue="condition"
        )
        sns.stripplot(
            data, 
            x='condition', #Change to condition if we want to plot individual points for each condition instead of each test object class
            y='filtered_acc', 
            hue='condition',
            palette='magma', 
            ax=ax1, 
            size=3.5, 
            edgecolor='black', 
            linewidth= 1.5, 
            marker='o',
            alpha = 0.75,
            jitter=True,  # Add jitter to avoid overlapping points
        )
    elif extreme == True:
        sns.pointplot(
            data=data,
            x="stimulus_duration",
            y="filtered_acc",
            hue="condition",
            palette="magma",
            order=[0.3, 0.136, 0.068, 0.034],
            capsize=0.2,
            errorbar= ("ci", 95)
        )
    
    ax1.set_ylim(0, 1.0)
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Condition')
    ax1.axhline(y=chance, color='black', linestyle='--', linewidth=1.5, zorder=11)
    return plt.gca()

# %% [markdown]
# # Run the Preprocessing and Exclusion Functions
# Experiment 1: Familiar Original
#
# Experiment 2: Familiar Extreme
#
# Experiment 3: Novel Orginal
#
# Experiment 4: Novel Extreme

# %% [markdown]
# ## Familiar Original

# %%
#Run the preprocessing pipeline for familiar Original version, experiment = 'familiar' and extreme = False
sub_summary, experiment, extreme = preprocessing_pipeline('familiar', False)
# Out:
# You have selected familiar glint experiment
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/6678813aec86d687a654dedb_familiar_glint_final_2025-11-19_10h28.44.237.csv
#
# Processing Subject: 6678813aec86d687a654dedb
#   Practice trials accuracy looks good for 6678813aec86d687a654dedb, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/5db0e17518230d00170d4332_familiar_glint_final_2025-11-19_11h19.45.749.csv
#
# Processing Subject: 5db0e17518230d00170d4332
#   Practice trials accuracy looks good for 5db0e17518230d00170d4332, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/5aa2dcf36219a30001f57b7e_familiar_glint_final_2025-11-19_11h04.21.674.csv
#
# Processing Subject: 5aa2dcf36219a30001f57b7e
#   Practice trials accuracy looks good for 5aa2dcf36219a30001f57b7e, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/67819f666062825529fe313e_familiar_glint_final_2025-11-19_09h22.31.058.csv
#
# Processing Subject: 67819f666062825529fe313e
#   Practice trials accuracy looks good for 67819f666062825529fe313e, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/67e85a8becc5f7048616c4be_familiar_glint_final_2025-11-18_10h13.33.213.csv
#
# Processing Subject: 67e85a8becc5f7048616c4be
#   Practice trials accuracy looks good for 67e85a8becc5f7048616c4be, Accuracy =  0.800
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint
Accuracy =  0.800
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/66cec5a3fdf1fe2c010e9971_familiar_glint_final_2025-11-19_10h33.29.491.csv
#
# Processing Subject: 66cec5a3fdf1fe2c010e9971
#   Caution: Low accuracy in practice trials for 66cec5a3fdf1fe2c010e9971 Accuracy =  0.400. Check data quality.
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/672931da14bedacc4b738eb7_familiar_glint_final_2025-11-19_12h21.23.378.csv
#
# Processing Subject: 672931da14bedacc4b738eb7
#   Practice trials accuracy looks good for 672931da14bedacc4b738eb7, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint/67e1dc9c35b6facf1079fb30_familiar_glint_final_2025-11-19_17h24.10.758.csv
#
# Processing Subject: 67e1dc9c35b6facf1079fb30
#   Practice trials accuracy looks good for 67e1dc9c35b6facf1079fb30, Accuracy =  1.000

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the familiar original version, experiment = 'familiar' and extreme = False

chance = chance_calculator(experiment, extreme)
print(f"Running Exclusion check for experiment = {experiment}, extreme = {extreme}, chance level = {chance:.3f}")

flagged = exclusion_check(sub_summary,chance) #Flag subjects based on exclusion criteria

sub_summary_cleaned = remove_flagged_subjects(sub_summary, 
                                              flagged, 
                                              delete=True) # Remove flagged subjects

familiar_original_long_df, familiar_original_wide_df = create_wide_df_save(sub_summary_cleaned,
                                                                        experiment,
                                                                        extreme, 
                                                                        output_path = '/zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/') # Create wide format



plot_summary(familiar_original_long_df, extreme,chance)
# Out:
# Calculated chance level based on 9 choices: 0.111
# Running Exclusion check for experiment = familiar, extreme = False, chance level = 0.111
# Natural condition: mean = 0.952, sd = 0.108, threshold (mean - 2sd) = 0.736
# Chance threshold = 0.111
# Found 0 subject(s) below chance:
# Threshold for exclusion (mean - 2sd) = 0.736
# Found 2 subject(s) below or equal to threshold:
#                           id  natural_filtered_acc
# 34  66afcaa60f7d8f58dc21db8e              0.321637
# 37  66cec5a3fdf1fe2c010e9971              0.639163
# Flagged 2 subject(s) total for exclusion:
#                           id  natural_filtered_acc
# 34  66afcaa60f7d8f58dc21db8e              0.321637
# 37  66cec5a3fdf1fe2c010e9971              0.639163
# Flagged subjects to remove (2):
#                           id  natural_filtered_acc
# 34  66afcaa60f7d8f58dc21db8e              0.321637
# 37  66cec5a3fdf1fe2c010e9971              0.639163
# Preview: 18 rows (of 468) belong to flagged subject(s).
# Removed 18 rows.
# Final cleaned sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/familiar_glint_original_cleaned.csv
# Final cleaned wide-format sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/familiar_glint_original_cleaned_wide.csv
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %% [markdown]
# ## Familiar Extreme

# %%
#Run the preprocessing pipeline for familiar Extreme version, experiment = 'familiar' and extreme = True
sub_summary, experiment, extreme = preprocessing_pipeline('familiar', True)
# Out:
# You have selected familiar glint extreme experiment
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/667ef3c6b1ce7f18e774b31b_familiar_glint_extreme_2025-12-10_13h19.52.829.csv
#
# Processing Subject: 667ef3c6b1ce7f18e774b31b
#   Practice trials accuracy looks good for 667ef3c6b1ce7f18e774b31b, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/663a8c84b8e7c046d854c8dd_familiar_glint_extreme_2025-12-10_12h56.43.428.csv
#
# Processing Subject: 663a8c84b8e7c046d854c8dd
#   Practice trials accuracy looks good for 663a8c84b8e7c046d854c8dd, Accuracy =  0.800
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme
Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/66746db831e815ded8e9eaf3_familiar_glint_extreme_2025-12-10_12h59.18.627.csv
#
# Processing Subject: 66746db831e815ded8e9eaf3
#   Practice trials accuracy looks good for 66746db831e815ded8e9eaf3, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/65e33239b5fa3ca93950aa67_familiar_glint_extreme_2025-12-10_13h21.52.259.csv
#
# Processing Subject: 65e33239b5fa3ca93950aa67
#   Practice trials accuracy looks good for 65e33239b5fa3ca93950aa67, Accuracy =  0.800
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/675758f40df8b09c8aa98ad0_familiar_glint_extreme_2025-12-10_09h21.57.553.csv
#
# Processing Subject: 675758f40df8b09c8aa98ad0
#   Practice trials accuracy looks good for 675758f40df8b09c8aa98ad0, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/673dfad20de86492d4c66329_familiar_glint_extreme_2025-12-10_10h31.41.039.csv
#
# Processing Subject: 673dfad20de86492d4c66329
#   Practice trials accuracy looks good for 673dfad20de86492d4c66329, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/6722b6b9cb69415ce7f4c688_familiar_glint_extreme_2025-12-10_16h07.40.792.csv
#
# Processing Subject: 6722b6b9cb69415ce7f4c688
#   Practice trials accuracy looks good for 6722b6b9cb69415ce7f4c688, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/67828038b2e1f7607e817e11_familiar_glint_extreme_2025-12-10_15h30.58.125.csv
#
# Processing Subject: 67828038b2e1f7607e817e11
#   Practice trials accuracy looks good for 67828038b2e1f7607e817e11, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/5d153b1f40218700189a05df_familiar_glint_extreme_2025-12-10_10h49.55.306.csv
#
# Processing Subject: 5d153b1f40218700189a05df
#   Practice trials accuracy looks good for 5d153b1f40218700189a05df, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/familiar_glint_extreme/6475f1d696be138189f68303_familiar_glint_extreme_2025-12-10_12h24.05.639.csv
#
# Processing Subject: 6475f1d696be138189f68303
#   Practice trials accuracy looks good for 6475f1d696be138189f68303, Accuracy =  0.800

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the familiar extreme version, experiment = 'familiar' and extreme = True

chance = chance_calculator(experiment, extreme)
print(f"Running Exclusion check for experiment = {experiment}, extreme = {extreme}, chance level = {chance:.3f}")

flagged = exclusion_check(sub_summary,chance) #Flag subjects based on exclusion criteria

sub_summary_cleaned = remove_flagged_subjects(sub_summary, 
                                              flagged, 
                                              delete=True) # Remove flagged subjects

familiar_extreme_long_df, familiar_extreme_wide_df = create_wide_df_save(sub_summary_cleaned,
                                                                        experiment,
                                                                        extreme, 
                                                                        output_path = '/zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/') # Create wide format



plot_summary(familiar_extreme_long_df, extreme,chance)
# Out:
# Calculated chance level based on 6 choices: 0.167
# Running Exclusion check for experiment = familiar, extreme = True, chance level = 0.167
# Natural condition: mean = 0.836, sd = 0.098, threshold (mean - 2sd) = 0.641
# Chance threshold = 0.167
# Found 0 subject(s) below chance:
# Threshold for exclusion (mean - 2sd) = 0.641
# Found 3 subject(s) below or equal to threshold:
#                           id  natural_filtered_acc
# 43  6745f73ee7541460adbabcff              0.555556
# 25  6628f4e77ba6d4332996845e              0.612500
# 49  67aa80c774c81448a3876d15              0.638889
# Flagged 3 subject(s) total for exclusion:
#                           id  natural_filtered_acc
# 43  6745f73ee7541460adbabcff              0.555556
# 25  6628f4e77ba6d4332996845e              0.612500
# 49  67aa80c774c81448a3876d15              0.638889
# Flagged subjects to remove (3):
#                           id  natural_filtered_acc
# 43  6745f73ee7541460adbabcff              0.555556
# 25  6628f4e77ba6d4332996845e              0.612500
# 49  67aa80c774c81448a3876d15              0.638889
# Preview: 108 rows (of 1908) belong to flagged subject(s).
# Removed 108 rows.
# Final cleaned sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/familiar_glint_extreme_cleaned.csv
# Final cleaned wide-format sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/familiar_glint_extreme_cleaned_wide.csv
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %%
# ...existing code...
import re
from collections import defaultdict

# Pick the wide dataframe you want to inspect:
# wide_df = familiar_original_wide_df
# wide_df = familiar_extreme_wide_df
# wide_df = novel_original_wide_df
# wide_df = novel_extreme_wide_df
wide_df = familiar_extreme_wide_df  # <- change as needed

acc_cols = [c for c in wide_df.columns if isinstance(c, str) and c.startswith("filtered_acc_")]

grouped = defaultdict(list)
unmatched = []

for col in acc_cols:
    m = re.match(r"^filtered_acc_(natural|feature|shape)_", col)
    if m:
        grouped[m.group(1)].append(col)
    else:
        unmatched.append(col)

for condition in ["natural", "feature", "shape"]:
    cols = sorted(grouped.get(condition, []))
    print(f"\n{condition.upper()} ({len(cols)} columns):")
    for c in cols:
        print(f"  - {c}")

if unmatched:
    print("\nUNMATCHED filtered_acc columns (check naming):")
    for c in sorted(unmatched):
        print(f"  - {c}")
# ...existing code...
# Out:
# NATURAL (12 columns):
#   - filtered_acc_natural_0.034_anim_natural
#   - filtered_acc_natural_0.034_inanim_artificial
#   - filtered_acc_natural_0.034_inanim_natural
#   - filtered_acc_natural_0.068_anim_natural
#   - filtered_acc_natural_0.068_inanim_artificial
#   - filtered_acc_natural_0.068_inanim_natural
#   - filtered_acc_natural_0.136_anim_natural
#   - filtered_acc_natural_0.136_inanim_artificial
#   - filtered_acc_natural_0.136_inanim_natural
#   - filtered_acc_natural_0.3_anim_natural
#   - filtered_acc_natural_0.3_inanim_artificial
#   - filtered_acc_natural_0.3_inanim_natural
#
# FEATURE (12 columns):
#   - filtered_acc_feature_0.034_anim_natural
#   - filtered_acc_feature_0.034_inanim_artificial
#   - filtered_acc_feature_0.034_inanim_natural
#   - filtered_acc_feature_0.068_anim_natural
#   - filtered_acc_feature_0.068_inanim_artificial
#   - filtered_acc_feature_0.068_inanim_natural
#   - filtered_acc_feature_0.136_anim_natural
#   - filtered_acc_feature_0.136_inanim_artificial
#   - filtered_acc_feature_0.136_inanim_natural
#   - filtered_acc_feature_0.3_anim_natural
#   - filtered_acc_feature_0.3_inanim_artificial
#   - filtered_acc_feature_0.3_inanim_natural
#
# SHAPE (12 columns):
#   - filtered_acc_shape_0.034_anim_natural
#   - filtered_acc_shape_0.034_inanim_artificial
#   - filtered_acc_shape_0.034_inanim_natural
#   - filtered_acc_shape_0.068_anim_natural
#   - filtered_acc_shape_0.068_inanim_artificial
#   - filtered_acc_shape_0.068_inanim_natural
#   - filtered_acc_shape_0.136_anim_natural
#   - filtered_acc_shape_0.136_inanim_artificial
#   - filtered_acc_shape_0.136_inanim_natural
#   - filtered_acc_shape_0.3_anim_natural
#   - filtered_acc_shape_0.3_inanim_artificial
#   - filtered_acc_shape_0.3_inanim_natural

# %%
natural_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_natural_")]
feature_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_feature_")]
shape_cols   = [c for c in wide_df.columns if c.startswith("filtered_acc_shape_")]

natural_accuracy = wide_df[natural_cols].sum(axis=1, skipna=True) / len(natural_cols)
feature_accuracy = wide_df[feature_cols].sum(axis=1, skipna=True) / len(feature_cols)
shape_accuracy   = wide_df[shape_cols].sum(axis=1, skipna=True) / len(shape_cols)

wide_df["filtered_acc_natural_overall"] = natural_accuracy
wide_df["filtered_acc_feature_overall"] = feature_accuracy
wide_df["filtered_acc_shape_overall"]   = shape_accuracy

# %%
natural_accuracy =   filtered_acc_natural_0.034_anim_natural
  - filtered_acc_natural_0.034_inanim_artificial
  - filtered_acc_natural_0.034_inanim_natural
  - filtered_acc_natural_0.068_anim_natural
  - filtered_acc_natural_0.068_inanim_artificial
  - filtered_acc_natural_0.068_inanim_natural
  - filtered_acc_natural_0.136_anim_natural
  - filtered_acc_natural_0.136_inanim_artificial
  - filtered_acc_natural_0.136_inanim_natural
  - filtered_acc_natural_0.3_anim_natural
  - filtered_acc_natural_0.3_inanim_artificial
  - filtered_acc_natural_0.3_inanim_natural

shape_accuracy = 

feature_accuracy

# %% [markdown]
# ## Novel Original

# %%
#Run the preprocessing pipeline for Novel Original version, experiment = 'novel' and extreme = False
sub_summary, experiment, extreme = preprocessing_pipeline('novel', False)
# Out:
# You have selected novel glint experiment
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/66293da691cec8862619b1dc_novel_glint_final_2025-11-19_10h37.07.348.csv
#
# Processing Subject: 66293da691cec8862619b1dc
#   Practice trials accuracy looks good for 66293da691cec8862619b1dc, Accuracy =  0.750
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/62713a003caa3feec5c6a0ba_novel_glint_final_2025-11-19_10h54.33.461.csv
#
# Processing Subject: 62713a003caa3feec5c6a0ba
#   Practice trials accuracy looks good for 62713a003caa3feec5c6a0ba, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/661ae93e33b51f5d31a8c3bb_novel_glint_final_2025-11-19_07h55.09.601.csv
#
# Processing Subject: 661ae93e33b51f5d31a8c3bb
#   Practice trials accuracy looks good for 661ae93e33b51f5d31a8c3bb, Accuracy =  0.938
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/6671c66b6e4bc111961291ae_novel_glint_final_2025-11-19_10h57.54.953.csv
#
# Processing Subject: 6671c66b6e4bc111961291ae
#   Practice trials accuracy looks good for 6671c66b6e4bc111961291ae, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/680dcb74ab0a3a21ef2d6d89_novel_glint_final_2025-11-19_11h21.29.779.csv
#
# Processing Subject: 680dcb74ab0a3a21ef2d6d89
#   Caution: Low accuracy in practice trials for 680dcb74ab0a3a21ef2d6d89 Accuracy =  0.438. Check data quality.
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/662fecef2a008847dc4f0d9b_novel_glint_final_2025-11-19_11h15.07.872.csv
#
# Processing Subject: 662fecef2a008847dc4f0d9b
#   Practice trials accuracy looks good for 662fecef2a008847dc4f0d9b, Accuracy =  0.938
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint
Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/614e951047173bf040153e8e_novel_glint_final_2025-11-19_09h54.04.787.csv
#
# Processing Subject: 614e951047173bf040153e8e
#   Practice trials accuracy looks good for 614e951047173bf040153e8e, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/610329975d39376c37360d3c_novel_glint_final_2025-11-19_11h24.12.793.csv
#
# Processing Subject: 610329975d39376c37360d3c
#   Practice trials accuracy looks good for 610329975d39376c37360d3c, Accuracy =  0.875
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/632b9d9bc38454f47019295c_novel_glint_final_2025-11-19_13h54.30.591.csv
#
# Processing Subject: 632b9d9bc38454f47019295c
#   Practice trials accuracy looks good for 632b9d9bc38454f47019295c, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/6033a745a39025078ff19a17_novel_glint_final_2026-01-09_12h59.00.650.csv
#
# Processing Subject: 6033a745a39025078ff19a17
#   Caution: Low accuracy in practice trials for 6033a745a39025078ff19a17 Accuracy =  0.125. Check data quality.
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/62c3430ae19d78462af9e743_novel_glint_final_2025-11-19_11h14.49.273.csv
#
# Processing Subject: 62c3430ae19d78462af9e743
#   Practice trials accuracy looks good for 62c3430ae19d78462af9e743, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/66a398080da27efcc3e8ecef_novel_glint_final_2025-11-19_11h50.31.441.csv
#
# Processing Subject: 66a398080da27efcc3e8ecef
#   Practice trials accuracy looks good for 66a398080da27efcc3e8ecef, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/5fff0f626abf51640c57419e_novel_glint_final_2025-11-19_11h12.22.645.csv
#
# Processing Subject: 5fff0f626abf51640c57419e
#   Practice trials accuracy looks good for 5fff0f626abf51640c57419e, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/6714d7f42c208253099ac9d9_novel_glint_final_2025-11-19_11h24.42.454.csv
#
# Processing Subject: 6714d7f42c208253099ac9d9
#   Practice trials accuracy looks good for 6714d7f42c208253099ac9d9, Accuracy =  0.625
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/59107216127b0b00011fabea_novel_glint_final_2025-11-19_08h22.31.870.csv
#
# Processing Subject: 59107216127b0b00011fabea
#   Practice trials accuracy looks good for 59107216127b0b00011fabea, Accuracy =  0.500
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/58a0c507890ea500014c4e9b_novel_glint_final_2025-11-19_11h17.26.298.csv
#
# Processing Subject: 58a0c507890ea500014c4e9b
#   Practice trials accuracy looks good for 58a0c507890ea500014c4e9b, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/6647d385a03fca12ce7acc45_novel_glint_final_2025-11-19_11h03.54.146.csv
#
# Processing Subject: 6647d385a03fca12ce7acc45
#   Practice trials accuracy looks good for 6647d385a03fca12ce7acc45, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/65ca7b52b557f4aa965301ef_novel_glint_final_2025-11-19_09h58.41.031.csv
#
# Processing Subject: 65ca7b52b557f4aa965301ef
#   Practice trials accuracy looks good for 65ca7b52b557f4aa965301ef, Accuracy =  0.938
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/54924b8efdf99b77ccedc1d5_novel_glint_final_2025-11-19_08h01.11.586.csv
#
# Processing Subject: 54924b8efdf99b77ccedc1d5
#   Practice trials accuracy looks good for 54924b8efdf99b77ccedc1d5, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/6785704c3b1ab8813a4958b0_novel_glint_final_2025-11-19_07h54.19.819.csv
#
# Processing Subject: 6785704c3b1ab8813a4958b0
#   Practice trials accuracy looks good for 6785704c3b1ab8813a4958b0, Accuracy =  0.938
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/65c12aec64a50727ccd1ac6e_novel_glint_final_2025-11-19_11h09.05.450.csv
#
# Processing Subject: 65c12aec64a50727ccd1ac6e
#   Practice trials accuracy looks good for 65c12aec64a50727ccd1ac6e, Accuracy =  0.500
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/645179915e31c1aeb3dc8129_novel_glint_final_2025-11-19_11h18.48.036.csv
#
# Processing Subject: 645179915e31c1aeb3dc8129
#   Caution: Low accuracy in practice trials for 645179915e31c1aeb3dc8129 Accuracy =  0.188. Check data quality.
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/5f4ee7ff2c5da213f015a27e_novel_glint_final_2025-11-19_10h17.05.014.csv
#
# Processing Subject: 5f4ee7ff2c5da213f015a27e
#   Practice trials accuracy looks good for 5f4ee7ff2c5da213f015a27e, Accuracy =  0.938
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint/59f71f797086f80001941493_novel_glint_final_2025-11-19_07h56.20.932.csv
#
# Processing Subject: 59f71f797086f80001941493
#   Practice trials accuracy looks good for 59f71f797086f80001941493, Accuracy =  1.000

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the novel original version, experiment = 'novel' and extreme = False

chance = chance_calculator(experiment, extreme)
print(f"Running Exclusion check for experiment = {experiment}, extreme = {extreme}, chance level = {chance:.3f}")

flagged = exclusion_check(sub_summary,chance) #Flag subjects based on exclusion criteria

sub_summary_cleaned = remove_flagged_subjects(sub_summary, 
                                              flagged, 
                                              delete=True) # Remove flagged subjects

novel_original_long_df, novel_original_wide_df = create_wide_df_save(sub_summary_cleaned,
                                                                        experiment,
                                                                        extreme, 
                                                                        output_path = '/zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/') # Create wide format



plot_summary(novel_original_long_df, extreme, chance)
# Out:
# Calculated chance level based on 4 choices: 0.250
# Running Exclusion check for experiment = novel, extreme = False, chance level = 0.250
# Natural condition: mean = 0.671, sd = 0.247, threshold (mean - 2sd) = 0.176
# Chance threshold = 0.250
# Found 3 subject(s) below chance:
#                           id  natural_filtered_acc
# 37  66a398080da27efcc3e8ecef              0.142857
# 43  670efd496f9f47e38a4b1d7d              0.216216
# 5   5aed18cf026e1300018199b3              0.230769
# Threshold for exclusion (mean - 2sd) = 0.176
# Found 1 subject(s) below or equal to threshold:
#                           id  natural_filtered_acc
# 37  66a398080da27efcc3e8ecef              0.142857
# Subjects below chance combined with subjects below 2SD threshold.
# Flagged 3 subject(s) total for exclusion:
#                          id  natural_filtered_acc
# 0  66a398080da27efcc3e8ecef              0.142857
# 3  670efd496f9f47e38a4b1d7d              0.216216
# 1  5aed18cf026e1300018199b3              0.230769
# Flagged subjects to remove (3):
#                          id  natural_filtered_acc
# 0  66a398080da27efcc3e8ecef              0.142857
# 3  670efd496f9f47e38a4b1d7d              0.216216
# 1  5aed18cf026e1300018199b3              0.230769
# Preview: 9 rows (of 159) belong to flagged subject(s).
# Removed 9 rows.
# Final cleaned sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/novel_glint_original_cleaned.csv
# Final cleaned wide-format sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/novel_glint_original_cleaned_wide.csv
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %% [markdown]
# ## Novel Extreme

# %%
#Run the preprocessing pipeline for Novel Extreme version, experiment = 'novel' and extreme = True
sub_summary, experiment, extreme = preprocessing_pipeline('novel', True)
# Out:
# You have selected novel glint extreme experiment
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme
Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/66d767c9f152fec7cd93cb55_novel_glint_extreme_2025-12-10_13h26.48.999.csv
#
# Processing Subject: 66d767c9f152fec7cd93cb55
#   Practice trials accuracy looks good for 66d767c9f152fec7cd93cb55, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/5f0a686635f72917e94c7a63_novel_glint_extreme_2025-12-10_11h15.14.655.csv
#
# Processing Subject: 5f0a686635f72917e94c7a63
#   Practice trials accuracy looks good for 5f0a686635f72917e94c7a63, Accuracy =  0.875
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/6921ecd02bd2f70d30a9a555_novel_glint_extreme_2025-12-10_16h16.18.341.csv
#
# Processing Subject: 6921ecd02bd2f70d30a9a555
#   Practice trials accuracy looks good for 6921ecd02bd2f70d30a9a555, Accuracy =  0.875
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/66b2da98af11038f74282e8f_novel_glint_extreme_2025-12-10_12h36.11.102.csv
#
# Processing Subject: 66b2da98af11038f74282e8f
#   Practice trials accuracy looks good for 66b2da98af11038f74282e8f, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/671ce7ade7a5cd2edc847b94_novel_glint_extreme_2025-12-10_11h32.37.725.csv
#
# Processing Subject: 671ce7ade7a5cd2edc847b94
#   Practice trials accuracy looks good for 671ce7ade7a5cd2edc847b94, Accuracy =  1.000
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/5be745d20dd2f60001a212b6_novel_glint_extreme_2025-12-10_12h15.04.338.csv
#
# Processing Subject: 5be745d20dd2f60001a212b6
#   Practice trials accuracy looks good for 5be745d20dd2f60001a212b6, Accuracy =  0.812
#
# Processing file: /zpool/vladlab/data_drive/glint_data/novel_glint_extreme/66d77ebd93a13a53f4d6577b_novel_glint_extreme_2025-12-10_15h22.01.233.csv
#
# Processing Subject: 66d77ebd93a13a53f4d6577b
#   Practice trials accuracy looks good for 66d77ebd93a13a53f4d6577b, Accuracy =  0.500

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the Novel extreme version, experiment = 'novel' and extreme = True

chance = chance_calculator(experiment, extreme)
print(f"Running Exclusion check for experiment = {experiment}, extreme = {extreme}, chance level = {chance:.3f}")

flagged = exclusion_check(sub_summary,chance) #Flag subjects based on exclusion criteria

sub_summary_cleaned = remove_flagged_subjects(sub_summary, 
                                              flagged, 
                                              delete=True) # Remove flagged subjects

novel_extreme_long_df, novel_extreme_wide_df = create_wide_df_save(sub_summary_cleaned,
                                                                        experiment,
                                                                        extreme, 
                                                                        output_path = '/zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/') # Create wide format



plot_summary(novel_extreme_long_df, extreme,chance)
# Out:
# Calculated chance level based on 4 choices: 0.250
# Running Exclusion check for experiment = novel, extreme = True, chance level = 0.250
# Natural condition: mean = 0.585, sd = 0.185, threshold (mean - 2sd) = 0.215
# Chance threshold = 0.250
# Found 0 subject(s) below chance:
# Threshold for exclusion (mean - 2sd) = 0.215
# Found 0 subject(s) below or equal to threshold:
# No subjects are below (or equal to) mean - 2*SD for natural filtered accuracy.
# No subjects to remove based on exclusion criteria.
# Final cleaned sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/novel_glint_extreme_cleaned.csv
# Final cleaned wide-format sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/novel_glint_extreme_cleaned_wide.csv
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %%
import os
import glob
import pandas as pd

# --- set this to the dataset where you saw the missing value ---
experiment = "familiar"   # or "novel"
version = "extreme"       # 0.034 only exists in extreme

clean_path = f"/zpool/vladlab/data_drive/glint_data/summary_data_csv/{experiment}_glint_{version}_cleaned.csv"
raw_dir = f"/zpool/vladlab/data_drive/glint_data/{experiment}_glint_{version}"

clean = pd.read_csv(clean_path)

# Normalize animacy text
clean["animacy_norm"] = clean["animacy"].astype(str).str.strip().str.lower()

# Find subject(s) with missing filtered_acc for the requested cell
target = clean[
    (clean["condition"] == "natural") &
    (clean["stimulus_duration"] == 0.034) &
    (clean["animacy_norm"] == "inanim_artificial") &
    (clean["filtered_acc"].isna())
]

print("Subjects with missing filtered_acc in requested cell:")
print(target[["sub", "condition", "stimulus_duration", "animacy", "filtered_acc"]])

subs = target["sub"].dropna().unique().tolist()
if not subs:
    print("\nNo missing value found for that exact cell.")
else:
    # Count raw trials for each affected subject
    files = glob.glob(os.path.join(raw_dir, "*.csv"))
    for sub in subs:
        sub_df = None
        for f in files:
            d = pd.read_csv(f)
            if "participant" in d.columns and str(d.loc[0, "participant"]) == str(sub):
                sub_df = d.copy()
                break

        if sub_df is None:
            print(f"\n{sub}: raw file not found.")
            continue

        # Match preprocessing column renaming
        sub_df = sub_df.rename(columns={
            "img_condition": "condition",
            "object_category": "animacy",
            "img_class": "test_object_class",
            "object_class": "test_object_class",
        })

        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        sub_df["condition"] = sub_df["condition"].replace(condition_mapping)
        sub_df["animacy_norm"] = sub_df["animacy"].astype(str).str.strip().str.lower()

        cell = sub_df[
            (sub_df["condition"] == "natural") &
            (sub_df["stimulus_duration"] == 0.034) &
            (sub_df["animacy_norm"] == "inanim_artificial")
        ]

        no_resp = (cell["response_label"] == "no response").sum()
        rt_ok = cell[(cell["response_label"] != "no response") & (cell["key_resp.rt"] >= 0.100)]

        # Same outlier logic as your script
        rt_series = rt_ok["key_resp.rt"].dropna()
        mean_rt = rt_series.mean()
        std_rt = rt_series.std(ddof=1)

        if len(rt_series) < 2 or pd.isna(std_rt):
            final_trials = rt_ok
        else:
            final_trials = rt_ok[rt_ok["key_resp.rt"].between(mean_rt - 2*std_rt, mean_rt + 2*std_rt)]

        print(f"\nSubject {sub}:")
        print(f"  total trials in cell                  = {len(cell)}")
        print(f"  no-response trials                    = {no_resp}")
        print(f"  trials after no-response + RT>=100ms  = {len(rt_ok)}")
        print(f"  final trials after ±2SD filter        = {len(final_trials)}")
# Out:
# Subjects with missing filtered_acc in requested cell:
#                            sub condition  stimulus_duration  \
# 1487  62964d27c2b2866faa677493   natural              0.034
#
#                 animacy  filtered_acc
# 1487  inanim_artificial           NaN
#
# Subject 62964d27c2b2866faa677493:
#   total trials in cell                  = 6
#   no-response trials                    = 0
#   trials after no-response + RT>=100ms  = 1
#   final trials after ±2SD filter        = 1

# %% [markdown]
# ## Mini-Glint

# %%
#Clear previous output and variables to ensure no mixing of the data
# %reset -f

# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb

def mini_glint_preprocessing_pipeline(experiment, mini=True):

    settings = {'experiment': experiment, 'mini': mini }
    
    experiment = settings['experiment'] #version of the experiment: novel only

    mini = settings['mini'] # Sets mini flag to check if this is the mini version of the experiment or not

    animacy = 'inanim_artificial'

    img_classes = ['krar', 'sistrum', 'sarangi', 'sheng']


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                'test_object_class', #test object class 
                'practice_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'number_of_no_responses', #number of no responses
                'number_of_fast_responses', #number of fast responses (RT < 100ms)
                'pre_filter_trial_count', #number of trials before any exclusions
                'final_trial_count', #number of trials after all exclusions
                'number_of_outliers', #number of RT outliers
                'number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses)
    

    #Create an empty dataframe to hold the summary data for all subjects and conditions, this will be populated in the loop through the files
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data

    #Mini should equal True, if false you are using wrong pipeline
    if mini == True:
        base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
        core_path = f'{base}/mini_glint' #default core path for mini version
    elif mini == False:
        print("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline.")
        raise ValueError("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline.")

    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
        except Exception as e:
            print(f"Failed to read {file}: {e}")
            raise ValueError("No file by this name.")
        
        # Check if the 'participant' column is in the data, if not, print an error message and raise a ValueError to skip this file and move on to the next one.
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")
            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

        #rename the columns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # If test_condition == 1 then condition is feature, if test_condition == 2 then condition is shape
        if data['test_condition'].iloc[0] == 1:
            conditions = 'feature'
        elif data['test_condition'].iloc[0] == 2:
            conditions = 'shape'
        

        '''
        if you dont want trial level summary of data, then just change img_class to condition like so:
        for condition in conditions:
            and then you can remove the test_object_class from the row dictionary and the base_cols list
        '''
        # Loop through each image class
        for img_class in img_classes:            
            # Check for required columns
            needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition']  #list of needed columns for processing

            # print out the available columns, required columns, and any missing columns for debugging purposes
            print(f"\n  Available columns: {data.columns.tolist()}")
            print(f"  Required columns: {needed}")
            missing_cols = [col for col in needed if col not in data.columns]
            if missing_cols:
                print(f"  MISSING: {missing_cols}")

            if any(col not in data.columns for col in needed): 
                print(f"Missing expected columns in {file}") 
                raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
            
              
            # Use trials function to import trials and filter based on current parameters
            trials = data[(data['test_object_class'] == img_class)]

            #trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]
    
            # Check if trials is None or empty, and will raise an error if so
            if trials is None or len(trials) == 0:
                print(f"  No trials found for {img_class}")
                raise ValueError("No trials found.")

            # Takes only trials with a response, and counts the number of no responses
            no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
            number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses

            '''
            Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
            Exclusion Criteria 2: RTs outside mean ± 2*SD
            We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
            and then we apply the RT filters to those trials. This way we can accurately count 
            the number of no responses, fast responses, and RT outliers separately.
            '''

            #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
            rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
            number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms

            #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
            #rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
            #mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
            #std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT

            # As we only have for trials we can not apply standard deviation based filtering, so we will skip that step and not filter out any RTs based on the mean ± 2*SD criterion, and we will set the number of outliers to 0 for this case
            final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion

            # Calculate the number of no responses and fast responses that were excluded based on the filters applied
            number_of_excluded_trials = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers

            # Calculate total number of trials for this subject
            total_trials = len(final_trials) #total number of trials for this subject and condition before any exclusions

            #Calculate the filtered accuracy after applying the response and RT filters
            filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   

            #Combines the experiment and extreme parameters into a single label for the summary dataframe
            experiment_label = f"mini_{experiment}_glint"  #combine experiment and extreme status into a single label for the summary dataframe    


            #Compiles all the variables of interest into a row for the condition summary dataframe
            row = {
                'experiment_label': experiment_label, #experiment and extreme status
                'id': sub, #subject identifier
                'condition': conditions, #condition (natural, scrambled, line_drawing)
                'stimulus_duration': 0.3, #stimulus duration (only if extreme is True)
                'animacy': animacy, #animacy (only if animacy_inclusion is True)
                'test_object_class': img_class, #test object class (only if test_object_class_inclusion is True)
                'practice_acc': practice_trials, #accuracy in practice trials
                'filtered_acc': filtered_acc, #accuracy after filtering
                'number_of_no_responses': number_of_no_responses, #number of no responses
                'number_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
                'pre_filter_trial_count': len(trials), #number of trials before any exclusions
                'final_trial_count': total_trials, #number of trials after all exclusions
                'number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
            }

            # Add the row to the condition summary
            condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

        # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, mini  # return config so downstream steps use the same values

# Quick Visualization
def plot_summary(data, extreme,chance):
    import seaborn as sns
    import matplotlib.pyplot as plt

    fig, ax1 = plt.subplots(figsize=(8, 5))
    if extreme == False:
        sns.barplot(
            data=data,
            x="condition",
            y="filtered_acc",
            ax = ax1,
            capsize=0.3,
            errorbar=("ci", 95),
            palette="magma",
            zorder=2,
            hue="condition"
        )
        sns.stripplot(
            data, 
            x='condition', #Change to condition if we want to plot individual points for each condition instead of each test object class
            y='filtered_acc', 
            hue='condition',
            palette='magma', 
            ax=ax1, 
            size=3.5, 
            edgecolor='black', 
            linewidth= 1.5, 
            marker='o',
            alpha = 0.75,
            jitter=True,  # Add jitter to avoid overlapping points
        )
    elif extreme == True:
        sns.pointplot(
            data=data,
            x="stimulus_duration",
            y="filtered_acc",
            hue="condition",
            palette="magma",
            order=[0.3, 0.136, 0.068, 0.034],
            capsize=0.2,
            errorbar= ("ci", 95)
        )
    
    ax1.set_ylim(0, 1.0)
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Condition')
    ax1.axhline(y=chance, color='black', linestyle='--', linewidth=1.5, zorder=11)
    return plt.gca()

# %%
def mini_glint_preprocessing_pipeline(experiment, mini=True):

    settings = {'experiment': experiment, 'mini': mini }
    
    experiment = settings['experiment'] #version of the experiment: novel only

    mini = settings['mini'] # Sets mini flag to check if this is the mini version of the experiment or not

    animacy = 'inanim_artificial'

    img_classes = ['krar', 'sistrum', 'sarangi', 'sheng']


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                'practice_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'number_of_no_responses', #number of no responses
                'number_of_fast_responses', #number of fast responses (RT < 100ms)
                'pre_filter_trial_count', #number of trials before any exclusions
                'final_trial_count', #number of trials after all exclusions
                'number_of_outliers', #number of RT outliers
                'number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses)
    

    #Create an empty dataframe to hold the summary data for all subjects and conditions, this will be populated in the loop through the files
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data

    #Mini should equal True, if false you are using wrong pipeline
    if mini == True:
        base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
        core_path = f'{base}/mini_glint' #default core path for mini version
    elif mini == False:
        print("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline.")
        raise ValueError("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline or use other pipelines.")

    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
        except Exception as e:
            print(f"Failed to read {file}: {e}")
            raise ValueError("No file by this name.")
        
        # Check if the 'participant' column is in the data, if not, print an error message and raise a ValueError to skip this file and move on to the next one.
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")
            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

        #rename the columns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # If test_condition == 1 then condition is feature, if test_condition == 2 then condition is shape
        if data['test_condition'].iloc[0] == 1:
            conditions = 'feature'
        elif data['test_condition'].iloc[0] == 2:
            conditions = 'shape'

        # Check for required columns
        needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition']  #list of needed columns for processing

        # print out the available columns, required columns, and any missing columns for debugging purposes
        print(f"\n  Available columns: {data.columns.tolist()}")
        print(f"  Required columns: {needed}")
        missing_cols = [col for col in needed if col not in data.columns]
        if missing_cols:
            print(f"  MISSING: {missing_cols}")

        if any(col not in data.columns for col in needed): 
            print(f"Missing expected columns in {file}") 
            raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
        
            
        # Use trials function to import trials and filter based on current parameters
        trials = data[(data['condition'] == conditions)]

        #trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]

        # Check if trials is None or empty, and will raise an error if so
        if trials is None or len(trials) == 0:
            print(f"  No trials found for {conditions}")
            raise ValueError("No trials found.")

        # Takes only trials with a response, and counts the number of no responses
        no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
        number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses

        '''
        Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
        Exclusion Criteria 2: RTs outside mean ± 2*SD
        We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
        and then we apply the RT filters to those trials. This way we can accurately count 
        the number of no responses, fast responses, and RT outliers separately.
        '''

        #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
        rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
        number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms

        #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
        #rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
        #mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
        #std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT

        # As we only have for trials we can not apply standard deviation based filtering, so we will skip that step and not filter out any RTs based on the mean ± 2*SD criterion, and we will set the number of outliers to 0 for this case
        final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion

        # Calculate the number of no responses and fast responses that were excluded based on the filters applied
        number_of_excluded_trials = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers

        # Calculate total number of trials for this subject
        total_trials = len(final_trials) #total number of trials for this subject and condition before any exclusions

        #Calculate the filtered accuracy after applying the response and RT filters
        filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   

        #Combines the experiment and extreme parameters into a single label for the summary dataframe
        experiment_label = f"mini_{experiment}_glint"  #combine experiment and extreme status into a single label for the summary dataframe    


        #Compiles all the variables of interest into a row for the condition summary dataframe
        row = {
            'experiment_label': experiment_label, #experiment and extreme status
            'id': sub, #subject identifier
            'condition': conditions, #condition (natural, scrambled, line_drawing)
            'stimulus_duration': 0.3, #stimulus duration (only if extreme is True)
            'animacy': animacy, #animacy (only if animacy_inclusion is True)
            'practice_acc': practice_trials, #accuracy in practice trials
            'filtered_acc': filtered_acc, #accuracy after filtering
            'number_of_no_responses': number_of_no_responses, #number of no responses
            'number_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
            'pre_filter_trial_count': len(trials), #number of trials before any exclusions
            'final_trial_count': total_trials, #number of trials after all exclusions
            'number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
        }

        # Add the row to the condition summary
        condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

        # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, mini  # return config so downstream steps use the same values

# %%
def exclusion_check(sub_summary,chance):
    """Returns per_sub DataFrame with natural condition accuracies per subject."""
    
    natural_acc = sub_summary[sub_summary['condition'] == 'natural'] # Filters for the condition of natural, and calculates the mean
    
    if natural_acc.empty:
        print("No 'natural' rows found in `sub_summary`.")
        # Return empty DataFrame with expected columns to avoid UnboundLocalError
        raise ValueError("No 'natural' rows found in sub_summary; cannot compute exclusion criteria.")
    
    per_sub = (
        natural_acc.groupby('id', as_index=False)['filtered_acc']
        .mean()
        .rename(columns={'filtered_acc': 'natural_filtered_acc'})
    )

    """Calculate threshold for exclusion based on mean - 2*SD of natural accuracies."""
    mean_nat = per_sub['natural_filtered_acc'].mean() #calculate mean of natural filtered accuracy
    sd_nat = per_sub['natural_filtered_acc'].std(ddof=1) #calculate standard deviation of natural filtered accuracy
    thresh = mean_nat - 2 * sd_nat #calculate threshold as mean - 2*SD
    print(f"Natural condition: mean = {mean_nat:.3f}, sd = {sd_nat:.3f}, threshold (mean - 2sd) = {thresh:.3f}") #print threshold values
    
    ''' Flag subjects below chance level and below 2SD threshold, and print results.'''
    flagged_below_chance = per_sub[per_sub['natural_filtered_acc'] <= chance].copy() #flag subjects below chance level
    
    print(f"Chance threshold = {chance:.3f}") 
    
    print(f"Found {len(flagged_below_chance)} subject(s) below chance:") 
    
    if not flagged_below_chance.empty: 
        
        print(flagged_below_chance.sort_values('natural_filtered_acc')) #print flagged subjects below chance level
    

    flagged = per_sub[per_sub['natural_filtered_acc'] <= thresh].copy() #flag subjects below 2SD threshold
    
    print(f"Threshold for exclusion (mean - 2sd) = {thresh:.3f}")
    
    print(f"Found {len(flagged)} subject(s) below or equal to threshold:")
    
    if not flagged.empty:
        
        print(flagged.sort_values('natural_filtered_acc'))
    
    # Combine with flagged_below_chance if any
    if not flagged_below_chance.empty:
        
        flagged = pd.concat([flagged, flagged_below_chance], ignore_index=True).drop_duplicates()  #combine flagged subjects below chance with those below 2SD threshold
        
        print("Subjects below chance combined with subjects below 2SD threshold.")
    
    if flagged.empty:
        print("No subjects are below (or equal to) mean - 2*SD for natural filtered accuracy.")

    else:
        print(f"Flagged {len(flagged)} subject(s) total for exclusion:")

        print(flagged.sort_values('natural_filtered_acc'))
    
    return flagged 

def remove_flagged_subjects(sub_summary, flagged, delete=True):
    if flagged.empty:

        print("No subjects to remove based on exclusion criteria.")

        return sub_summary.copy() #return original sub_summary if no flagged subjects
    
    flagged_df = flagged.copy() #make a copy of flagged subjects DataFrame

    print(f"Flagged subjects to remove ({len(flagged_df)}):")

    print(flagged_df.sort_values('natural_filtered_acc'))
    
    flagged_subs = set(flagged_df['id']) #get unique subject identifiers from flagged subjects

    n_rows_before = len(sub_summary) #count number of rows before removal

    n_rows_removed = sub_summary['id'].isin(flagged_subs).sum() #count number of rows to be removed
    print(f"Preview: {n_rows_removed} rows (of {n_rows_before}) belong to flagged subject(s).") 
    
    if delete:

        cleaned = sub_summary[~sub_summary['id'].isin(flagged_subs)].copy() #remove flagged subjects from sub_summary
        print(f"Removed {n_rows_removed} rows.")
    else:
        cleaned = sub_summary.copy() #keep original sub_summary if delete is False
        print("Delete=False: Keeping all rows in cleaned dataset.")
    
    return cleaned

# %%
#Run the preprocessing pipeline for Novel Extreme version, experiment = 'novel' and extreme = True
sub_summary, experiment, mini = mini_glint_preprocessing_pipeline(experiment= 'novel', mini=True)
# Out:
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/754555_mini_novel_glint_2026-04-27_10h48.43.934.csv
#
# Processing Subject: 754555
#   Practice trials accuracy looks good for 754555, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/735401_mini_novel_glint_2026-04-27_10h48.58.222.csv
#
# Processing Subject: 735401
#   Practice trials accuracy looks good for 735401, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/711088_mini_novel_glint_2026-04-27_08h46.32.891.csv
#
# Processing Subject: 711088
#   Practice trials accuracy looks good for 711088, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/606959_mini_novel_glint_2026-04-27_10h49.53.422.csv
#
# Processing Subject: 606959
#   Practice trials accuracy looks good for 606959, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/540551_mini_novel_glint_2026-04-27_10h49.07.326.csv
#
# Processing Subject: 540551
#   Practice trials accuracy looks good for 540551, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/296366_mini_novel_glint_2026-04-27_10h59.46.086.csv
#
# Processing Subject: 296366
#   Practice trials accuracy looks good for 296366, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/792731_mini_novel_glint_2026-04-27_10h59.51.958.csv
#
# Processing Subject: 792731
#   Practice trials accuracy looks good for 792731, Accuracy =  0.500
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/359694_mini_novel_glint_2026-04-27_10h48.16.438.csv
#
# Processing Subject: 359694
#   Practice trials accuracy looks good for 359694, Accuracy =  0.500
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/317217_mini_novel_glint_2026-04-27_09h56.11.231.csv
#
# Processing Subject: 317217
#   Practice trials accuracy looks good for 317217, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/116328_mini_novel_glint_2026-04-27_10h50.01.805.csv
#
# Processing Subject: 116328
#   Caution: Low accuracy in practice trials for 116328 Accuracy =  0.375. Check data quality.
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/363622_mini_novel_glint_2026-04-27_10h54.48.371.csv
#
# Processing Subject: 363622
#   Practice trials accuracy looks good for 363622, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/817248_mini_novel_glint_2026-04-27_09h46.46.542.csv
#
# Processing Subject: 817248
#   Practice trials accuracy looks good for 817248, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/690019_mini_novel_glint_2026-04-27_10h07.02.289.csv
#
# Processing Subject: 690019
#   Practice trials accuracy looks good for 690019, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/454675_mini_novel_glint_2026-04-27_09h57.02.496.csv
#
# Processing Subject: 454675
#   Practice trials accuracy looks good for 454675, Accuracy =  0.625
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/130072_mini_novel_glint_2026-04-27_10h57.25.435.csv
#
# Processing Subject: 130072
#   Practice trials accuracy looks good for 130072, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/380067_mini_novel_glint_2026-04-27_07h50.20.237.csv
#
# Processing Subject: 380067
#   Practice trials accuracy looks good for 380067, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/242337_mini_novel_glint_2026-04-27_11h56.11.246.csv
#
# Processing Subject: 242337
#   Practice trials accuracy looks good for 242337, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/346548_mini_novel_glint_2026-04-27_10h47.53.501.csv
#
# Processing Subject: 346548
#   Practice trials accuracy looks good for 346548, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/777857_mini_novel_glint_2026-04-27_10h52.56.001.csv
#
# Processing Subject: 777857
#   Practice trials accuracy looks good for 777857, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/700100_mini_novel_glint_2026-04-27_09h37.37.268.csv
#
# Processing Subject: 700100
#   Practice trials accuracy looks good for 700100, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/234360_mini_novel_glint_2026-04-27_10h51.24.722.csv
#
# Processing Subject: 234360
#   Practice trials accuracy looks good for 234360, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/639907_mini_novel_glint_2026-04-27_07h48.19.599.csv
#
# Processing Subject: 639907
#   Practice trials accuracy looks good for 639907, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/141399_mini_novel_glint_2026-04-27_09h51.18.103.csv
#
# Processing Subject: 141399
#   Practice trials accuracy looks good for 141399, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/866939_mini_novel_glint_2026-04-27_07h50.28.137.csv
#
# Processing Subject: 866939
#   Practice trials accuracy looks good for 866939, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/350828_mini_novel_glint_2026-04-27_09h48.43.430.csv
#
# Processing Subject: 350828
#   Practice trials accuracy looks good for 350828, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/306680_mini_novel_glint_2026-04-27_10h47.30.105.csv
#
# Processing Subject: 306680
#   Caution: Low accuracy in practice trials for 306680 Accuracy =  0.250. Check data quality.
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/886287_mini_novel_glint_2026-04-27_08h31.32.053.csv
#
# Processing Subject: 886287
#   Practice trials accuracy looks good for 886287, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/038078_mini_novel_glint_2026-04-27_10h51.04.122.csv
#
# Processing Subject: 38078
#   Practice trials accuracy looks good for 38078, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/237653_mini_novel_glint_2026-04-27_07h51.15.195.csv
#
# Processing Subject: 237653
#   Practice trials accuracy looks good for 237653, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/946497_mini_novel_glint_2026-04-27_10h47.30.911.csv
#
# Processing Subject: 946497
#   Practice trials accuracy looks good for 946497, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/176599_mini_novel_glint_2026-04-27_10h48.15.603.csv
#
# Processing Subject: 176599
#   Practice trials accuracy looks good for 176599, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/479234_mini_novel_glint_2026-04-27_07h56.59.429.csv
#
# Processing Subject: 479234
#   Practice trials accuracy looks good for 479234, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/747727_mini_novel_glint_2026-04-27_10h46.25.483.csv
#
# Processing Subject: 747727
#   Practice trials accuracy looks good for 747727, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/734531_mini_novel_glint_2026-04-27_11h59.28.395.csv
#
# Processing Subject: 734531
#   Practice trials accuracy looks good for 734531, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/254407_mini_novel_glint_2026-04-27_12h00.37.422.csv
#
# Processing Subject: 254407
#   Practice trials accuracy looks good for 254407, Accuracy =  0.500
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/957761_mini_novel_glint_2026-04-27_07h57.38.435.csv
#
# Processing Subject: 957761
#   Practice trials accuracy looks good for 957761, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/106060_mini_novel_glint_2026-04-27_11h07.16.643.csv
#
# Processing Subject: 106060
#   Practice trials accuracy looks good for 106060, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/919404_mini_novel_glint_2026-04-27_07h57.17.993.csv
#
# Processing Subject: 919404
#   Practice trials accuracy looks good for 919404, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/883223_mini_novel_glint_2026-04-27_09h52.45.898.csv
#
# Processing Subject: 883223
#   Practice trials accuracy looks good for 883223, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/942319_mini_novel_glint_2026-04-27_10h03.12.193.csv
#
# Processing Subject: 942319
#   Practice trials accuracy looks good for 942319, Accuracy =  0.750
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/788195_mini_novel_glint_2026-04-27_10h46.19.496.csv
#
# Processing Subject: 788195
#   Practice trials accuracy looks good for 788195, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/072745_mini_novel_glint_2026-04-27_10h53.23.455.csv
#
# Processing Subject: 72745
#   Practice trials accuracy looks good for 72745, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/976597_mini_novel_glint_2026-04-27_09h56.30.050.csv
#
# Processing Subject: 976597
#   Practice trials accuracy looks good for 976597, Accuracy =  0.625
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/861494_mini_novel_glint_2026-04-27_10h54.34.283.csv
#
# Processing Subject: 861494
#   Practice trials accuracy looks good for 861494, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/030761_mini_novel_glint_2026-04-27_07h48.21.183.csv
#
# Processing Subject: 30761
#   Practice trials accuracy looks good for 30761, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/052130_mini_novel_glint_2026-04-27_09h48.41.354.csv
#
# Processing Subject: 52130
#   Practice trials accuracy looks good for 52130, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/277151_mini_novel_glint_2026-04-27_07h56.59.949.csv
#
# Processing Subject: 277151
#   Practice trials accuracy looks good for 277151, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/264385_mini_novel_glint_2026-04-27_09h56.47.279.csv
#
# Processing Subject: 264385
#   Practice trials accuracy looks good for 264385, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/282524_mini_novel_glint_2026-04-27_10h35.35.145.csv
#
# Processing Subject: 282524
#   Practice trials accuracy looks good for 282524, Accuracy =  1.000
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/947395_mini_novel_glint_2026-04-27_07h57.03.815.csv
#
# Processing Subject: 947395
#   Practice trials accuracy looks good for 947395, Accuracy =  0.875
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the novel original version, experiment = 'novel' and extreme = False

plot_summary(sub_summary, extreme=False, chance=0.25)
# Out:
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %%
# exclude participants who have less than 2 trials 
sub_summary_filtered = sub_summary[sub_summary['num_trials_after_exclusion'] >= 2]
plot_summary(sub_summary_filtered, extreme, chance)
# Out:
# <Axes: xlabel='Condition', ylabel='Accuracy'>
