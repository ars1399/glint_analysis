# %% [markdown]
# # Glint Data Processing Master Script
#
# In this script each of the four versions of the glint experiment are able to be processed into a master data sheet for each experiment.
#
# The experiments include:
# (1) Original Familiar Glint
# (2) Original Novel Glint
# In both of these experiments, three conditions of transformed images are presented with only one stimulus duration.
#
# The second set of experiments include:
# (3) Familiar Glint Extreme
# (4) Novel Glint Extreme
# In these two versions, three conditions of transformed images are presented with 4 different stimulus durations.
#
# The distinction between familiar and novel is that familiar shows participants previously learned images, while novel presents unknown images that are learned and then tested on.
#
# The functions are split into two cells for the notebook for visualisation purposes, but for actual python script, they will grouped together at start of script.
#
# I highly recommend always resetting the variables before each version.

# %%
#Clear previous output and variables to ensure no mixing of the data
# %reset -f

# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb

# %% [markdown]
# ## Preprocessing and Exclusion Functions

# %%
def preprocessing_pipeline(experiment_type, is_extreme, mini):
    """Preprocess GLINT data based on experiment type and extreme flag.
    1. Sets experiment parameters.
    2. Loads data files.
    3. Loops through subjects, conditions, stimulus duration, and animacy to filter trials and calculate accuracy.
    4. Compiles results into a summary dataframe.
    
    Inputs: 
        experiment_type (str): 'novel' or 'familiar' to specify experiment version.
        is_extreme (bool): True for extreme version, False for original version.
        mini (bool): True for mini version, False for full version.
    Returns:
        sub_summary (pd.DataFrame): Summary dataframe with accuracy and trial counts.
        settings (dict): Configuration dictionary with experiment parameters.
        experiment (str): Experiment version used.
        extreme (bool): Extreme flag used.
    """

    ''' Experiment parameters and settings (1 & 2 are inputs, 3-7 defined by the inputs or hard coded)
    1. experiment (novel or familiar)
    2. extreme flag (True for extreme version, False for original version)
    3. durations (if extreme is True) 
    4. animacies 
    5. base path for data
    6. file paths for the selected experiment version
    7. base columns for summary dataframe
    '''
    settings = {'experiment': experiment_type,'extreme': is_extreme, 'mini': mini}
    
    experiment = settings['experiment'] #version of the experiment: familiar or novel

    extreme = settings['extreme'] # Sets extreme flag to determine if this is the extreme version of the experiment or not

    mini = settings['mini'] # Sets mini flag to determine if this is the mini version of the experiment or not

    if extreme == True:
        durations = [0.3, 0.136, 0.068, 0.034] if extreme == True else [None] #durations only matter if extreme is True
    elif extreme == False:
        durations = [0.3] #if not extreme, duration is not applicable

    if experiment == 'familiar':
        animacies = ['anim_natural', 'inanim_natural', 'inanim_artificial']
    
    elif experiment == 'novel':
        animacies = ['inanim_artificial'] #animacies for both versions of the experiment, but we define them here for clarity and consistency in the code structure


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                #'un_filtered_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'no_responses', #number of no responses
                'num_trials_after_exclusion', #number of trials after all exclusions
                'num_of_outliers', #number of RT outliers
                'num_of_fast_responses', #number of fast responses (RT < 100ms)
                'total_number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses + RT outliers)
    
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data


    #Need to differentiate the file paths based on if this is extreme or not
    base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
    
    if mini == True:
        core_path = f'{base}/mini_glint' # set core path for mini version using experiment variable and base path
        print(f' You have selected Mini-Glint experiment')
    elif mini == False: 
        print(f' You have selected the full version of the experiment, specifically:')
        if extreme == True:
            core_path = f'{base}/{experiment}_glint_extreme' # set core path using experiment variable and base path
            print(f"You have selected {experiment} glint extreme experiment")

        elif extreme == False: 
            core_path = f'{base}/{experiment}_glint' # set core path using experiment variable and base path
            print(f"You have selected {experiment} glint experiment")
        
    


    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        except Exception as e:
            print(f"Failed to read {file}: {e}")

            raise ValueError("No file by this name.")
        
    
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")

            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class",}

        #rename the colimns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # Loop through each condition
        if mini == True:
            conditions_to_process = ['feature', 'shape']
        else:
            conditions_to_process = ['natural', 'feature', 'shape']

        for condition in conditions_to_process:            
            # Check for required columns
            needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition',]  #list of needed columns for processing
            if extreme == True:
                needed.append('stimulus_duration') #if extreme is True, we also need the stimulus duration column for processing
            
            # Tells you exactly which columns are present or missing allowing for quick diagnosis of any issues with the data files.
            print(f"\n  Available columns: {data.columns.tolist()}")
            print(f"  Required columns: {needed}")
            missing_cols = [col for col in needed if col not in data.columns]
            if missing_cols:
                print(f"  MISSING: {missing_cols}")

            if mini == True and 'stimulus_duration' not in data.columns:
                print(f"  Adding missing 'stimulus_duration' column for mini version")
                data['stimulus_duration'] = 0.3  # Set default value
                missing_cols = [col for col in missing_cols if col != 'stimulus_duration']

            if any(col not in data.columns for col in needed): 
                print(f"Missing expected columns in {file}") 
                raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
            
            
            # Loop through stimulus durations and animacies if applicable
            for stimulus_duration in durations: 
                
                # Nested loop for animacy if applicable
                for animacy in animacies: #loop through each animacy
                    

                    # Use trials function to import trials and filter based on current parameters
                    if mini == True:
                        trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]
                    elif mini == False:
                        if extreme == False:
                            trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)] #if not extreme, we don't need to filter by stimulus duration, so we only filter by condition and animacy
                        
                        elif extreme == True:
                            trials = data[(data['condition'] == condition) & (data['stimulus_duration'] == stimulus_duration) & (data['animacy'] == animacy)]
                        
                    # Check if trials is None or empty, and will raise an error if so
                    if mini == False:
                        if trials is None or len(trials) == 0:
                            print(f"  No trials found for {condition}, {animacy}, {stimulus_duration}")
                            raise ValueError("No trials found.")
                    if mini == True:
                        if trials is None or len(trials) == 0:
                            print(f"  Skipping {condition} - no trials found for {animacy}, {stimulus_duration}")
                            continue  # Gracefully skip instead of erroring
                        
                    # Takes only trials with a response, and counts the number of no responses
                    no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
                    number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses


                    '''
                    Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
                    Exclusion Criteria 2: RTs outside mean ± 2*SD
                    We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
                    and then we apply the RT filters to those trials. This way we can accurately count 
                    the number of no responses, fast responses, and RT outliers separately.
                    '''

                    #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
                    rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
                    number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms
    

                    #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
                    rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
                    mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
                    std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT



                    #Filters out RTs outside mean ± 2*SD, and counts the number of RT outliers
                    if len(rt_plus_minus_2sd) < 2 or pd.isna(std_rt): #if there are less than 2 trials with RTs greater than 100ms, we cannot calculate a standard deviation, so we will skip this step and not filter out any RTs based on the mean ± 2*SD criterion
                        final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion
                    
                    else:
                        final_trials = rt_less_equal_100[rt_less_equal_100['key_resp.rt'].between(mean_rt - 2*std_rt, mean_rt + 2*std_rt)] #filter out RTs outside mean ± 2*SD

                    number_of_outliers = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers
                        

                    # Calculate the variables of interest and compile into a row for condition summary
                    #acc = trials['key_resp.corr'].mean() #accuracy before filtering (removed from final code as it is meant for debugging)
                    filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   
                    trial_count = len(final_trials) #number of trials after all exclusions


                    #Combines the experiment and extreme parameters into a single label for the summary dataframe
                    extreme_label = 'extreme' if extreme else 'original' #create label for extreme status

                    experiment_label = f"{experiment}_{extreme_label}"  #combine experiment and extreme status into a single label for the summary dataframe    

                    #sums up the total number of trials for this condition, stimulus duration, and animacy that were excluded based on the filters applied
                    number_of_excluded_trials = number_of_no_responses + number_of_fast_responses + number_of_outliers 

                    #Compiles all the variables of interest into a row for the condition summary dataframe
                    row = {
                        'experiment_label': experiment_label, #experiment and extreme status
                        'id': sub, #subject identifier
                        'condition': condition, #condition (natural, scrambled, line_drawing)
                        'stimulus_duration': stimulus_duration, #stimulus duration (only if extreme is True)
                        'animacy': animacy, #animacy (only if animacy_inclusion is True)
                        #'un_filtered_acc': acc, #accuracy before filtering
                        'filtered_acc': filtered_acc, #accuracy after filtering
                        'practice_acc': practice_trials, #accuracy in practice trials
                        'no_responses': number_of_no_responses, #number of no responses
                        'num_trials_after_exclusion': trial_count, #number of trials after all exclusions
                        'num_of_outliers': number_of_outliers, #number of RT outliers
                        'num_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
                        'total_number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
                    }

                    # Add the row to the condition summary
                    condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

        # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, extreme  # return config so downstream steps use the same values


'''
Exclusion Criteria Functions
Here we define the functions needed to do participant exclusion.
Our exclusion criteria are:
1. Participants with accuracy in the natural condition below chance level (calculated based on the number of response options for each experiment version).
2. Participants with accuracy in the natural condition below mean - 2*SD of the natural condition accuracies across all subjects.

Functions:
1. chance_calculator: Calculates the chance level based on the experiment version and extreme flag.
Inputs: experiment version (novel or familiar) and extreme flag (True or False)
Outputs: chance level (float)

2. exclusion_check: Identifies subjects to exclude based on the two criteria and prints the results
Inputs: sub_summary dataframe and chance level
Outputs: DataFrame of flagged subjects for exclusion

3. remove_flagged_subjects: Removes the flagged subjects from the sub_summary dataframe and returns the cleaned dataframe.
Inputs: sub_summary dataframe, flagged subjects dataframe, delete flag (True to remove, False to keep for review)
Outputs: cleaned sub_summary dataframe after removing flagged subjects (if delete=True), otherwise returns original sub_summary for review.

4. create_wide_format: Creates a wide-format version of the cleaned dataframe for downstream analyses.
Inputs: cleaned sub_summary dataframe
Outputs: cleaned long-format dataframe, cleaned wide-format dataframe, and saves both to CSV files with appropriate naming based on the experiment version and extreme flag.

5. plot_summary: Quick visualization function to plot the summary data for a quick check of the results after preprocessing.
'''

def chance_calculator(experiment, extreme):
    """Return the number of response options for the given experiment/extreme combo."""
    mapping = {
        ('novel', False): 4,
        ('novel', True): 4,
        ('familiar', True): 6,
        ('familiar', False): 9,
    }

    number_of_choices = mapping.get((experiment, extreme))

    chance = 1 / number_of_choices #formula for calculating chance 
    print(f"Calculated chance level based on {number_of_choices} choices: {chance:.3f}")
    return chance

def exclusion_check(sub_summary,chance):
    """Returns per_sub DataFrame with natural condition accuracies per subject."""
    
    natural_acc = sub_summary[sub_summary['condition'] == 'natural'] # Filters for the condition of natural, and calculates the mean
    
    if natural_acc.empty:
        print("No 'natural' rows found in `sub_summary`.")
        # Return empty DataFrame with expected columns to avoid UnboundLocalError
        raise ValueError("No 'natural' rows found in sub_summary; cannot compute exclusion criteria.")
    
    per_sub = (
        natural_acc.groupby('id', as_index=False)['filtered_acc']
        .mean()
        .rename(columns={'filtered_acc': 'natural_filtered_acc'})
    )

    """Calculate threshold for exclusion based on mean - 2*SD of natural accuracies."""
    mean_nat = per_sub['natural_filtered_acc'].mean() #calculate mean of natural filtered accuracy
    sd_nat = per_sub['natural_filtered_acc'].std(ddof=1) #calculate standard deviation of natural filtered accuracy
    thresh = mean_nat - 2 * sd_nat #calculate threshold as mean - 2*SD
    print(f"Natural condition: mean = {mean_nat:.3f}, sd = {sd_nat:.3f}, threshold (mean - 2sd) = {thresh:.3f}") #print threshold values
    
    ''' Flag subjects below chance level and below 2SD threshold, and print results.'''
    flagged_below_chance = per_sub[per_sub['natural_filtered_acc'] <= chance].copy() #flag subjects below chance level
    
    print(f"Chance threshold = {chance:.3f}") 
    
    print(f"Found {len(flagged_below_chance)} subject(s) below chance:") 
    
    if not flagged_below_chance.empty: 
        
        print(flagged_below_chance.sort_values('natural_filtered_acc')) #print flagged subjects below chance level
    

    flagged = per_sub[per_sub['natural_filtered_acc'] <= thresh].copy() #flag subjects below 2SD threshold
    
    print(f"Threshold for exclusion (mean - 2sd) = {thresh:.3f}")
    
    print(f"Found {len(flagged)} subject(s) below or equal to threshold:")
    
    if not flagged.empty:
        
        print(flagged.sort_values('natural_filtered_acc'))
    
    # Combine with flagged_below_chance if any
    if not flagged_below_chance.empty:
        
        flagged = pd.concat([flagged, flagged_below_chance], ignore_index=True).drop_duplicates()  #combine flagged subjects below chance with those below 2SD threshold
        
        print("Subjects below chance combined with subjects below 2SD threshold.")
    
    if flagged.empty:
        print("No subjects are below (or equal to) mean - 2*SD for natural filtered accuracy.")

    else:
        print(f"Flagged {len(flagged)} subject(s) total for exclusion:")

        print(flagged.sort_values('natural_filtered_acc'))
    
    return flagged 

def remove_flagged_subjects(sub_summary, flagged, delete=True):
    if flagged.empty:

        print("No subjects to remove based on exclusion criteria.")

        return sub_summary.copy() #return original sub_summary if no flagged subjects
    
    flagged_df = flagged.copy() #make a copy of flagged subjects DataFrame

    print(f"Flagged subjects to remove ({len(flagged_df)}):")

    print(flagged_df.sort_values('natural_filtered_acc'))
    
    flagged_subs = set(flagged_df['id']) #get unique subject identifiers from flagged subjects

    n_rows_before = len(sub_summary) #count number of rows before removal

    n_rows_removed = sub_summary['id'].isin(flagged_subs).sum() #count number of rows to be removed
    print(f"Preview: {n_rows_removed} rows (of {n_rows_before}) belong to flagged subject(s).") 
    
    if delete:

        cleaned = sub_summary[~sub_summary['id'].isin(flagged_subs)].copy() #remove flagged subjects from sub_summary
        print(f"Removed {n_rows_removed} rows.")
    else:
        cleaned = sub_summary.copy() #keep original sub_summary if delete is False
        print("Delete=False: Keeping all rows in cleaned dataset.")
    
    return cleaned


def create_wide_df_save(cleaned, experiment, extreme, mini, output_path):
    cleaned_wide = None
    
    #I kept running into errors when trying to create the wide format, so I wrapped it in a try except block to catch any errors and print them out
    try:
        values = ['filtered_acc', 'no_responses', 'num_trials_after_exclusion', 'num_of_outliers', 'num_of_fast_responses', 'total_number_of_excluded_trials'] #values to pivot on
        #values = ['un_filtered_acc', 'filtered_acc', 'no_responses', 'num_trials_after_exclusion', 'num_of_outliers', 'num_of_fast_responses', 'total_number_of_excluded_trials'] #values to pivot on

        pivot_df = cleaned.pivot(index='id', columns=['condition', 'stimulus_duration', 'animacy'], values=values) #pivot table with condition, stimulus_duration, and animacy as columns
        
        new_cols = [] #new column names list


        for col in pivot_df.columns: #loop through the columns in the pivoted dataframe to format the column names

            if len(col) == 3:
                metric, condition, duration = col #unpack the column tuple into metric, condition, and duration

                new_cols.append(f"{condition}_{duration}_{metric}") #format new column names

            else:
                new_cols.append("_".join([str(c) for c in col])) #join other columns as strings

        pivot_df.columns = new_cols #assign new column names to the pivoted dataframe

        pivot_df.reset_index(inplace=True) #reset index to make 'id' a column again

        cleaned_wide = pivot_df #assign pivoted DataFrame to cleaned_wide

        wide_df = cleaned_wide

        natural_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_natural") and c != "filtered_acc_natural_overall"]
        feature_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_feature") and c != "filtered_acc_feature_overall"]
        shape_cols   = [c for c in wide_df.columns if c.startswith("filtered_acc_shape")   and c != "filtered_acc_shape_overall"]

        natural_accuracy = wide_df[natural_cols].sum(axis=1, skipna=True) / len(natural_cols) if natural_cols else np.nan
        feature_accuracy = wide_df[feature_cols].sum(axis=1, skipna=True) / len(feature_cols) if feature_cols else np.nan
        shape_accuracy   = wide_df[shape_cols].sum(axis=1, skipna=True) / len(shape_cols) if shape_cols else np.nan

        wide_df["filtered_acc_natural_overall"] = natural_accuracy
        wide_df["filtered_acc_feature_overall"] = feature_accuracy
        wide_df["filtered_acc_shape_overall"]   = shape_accuracy

        cleaned_wide = wide_df
        
    except Exception as e:

        cleaned_wide = None #assign None to cleaned_wide if there was an error during pivoting

        print(f"Could not create wide-format: {e}") #alerts you if there was an error in pivoting data

    #Create a name for the final csv files based on the experiment version and extreme flag
    version = 'extreme' if extreme else 'original' #determine version based on extreme status

    final_csv = f'{experiment}_glint_{version}_cleaned.csv' #construct final CSV filename

    #Save the cleaned long-format
    cleaned.to_csv(os.path.join(output_path, final_csv), index=False) #save long-format DataFrame to CSV

    print(f"Final cleaned sub_summary saved to {os.path.join(output_path, final_csv)}") 

    # Save the wide-format DataFrame to CSV, if it was successfully created
    if cleaned_wide is not None:

        

        cleaned_wide.to_csv(os.path.join(output_path, f'{experiment}_glint_{version}_cleaned_wide.csv'), index=False) #save wide-format DataFrame to CSV

        print(f"Final cleaned wide-format sub_summary saved to {os.path.join(output_path, f'{experiment}_glint_{version}_cleaned_wide.csv')}")

    return cleaned, cleaned_wide

# Quick Visualization
def plot_summary(data, extreme,chance):
    import seaborn as sns
    import matplotlib.pyplot as plt

    fig, ax1 = plt.subplots(figsize=(8, 5))
    if extreme == False:
        sns.barplot(
            data=data,
            x="condition",
            y="filtered_acc",
            ax = ax1,
            capsize=0.3,
            errorbar=("ci", 95),
            palette="magma",
            zorder=2,
            hue="condition"
        )
        sns.stripplot(
            data, 
            x='condition', #Change to condition if we want to plot individual points for each condition instead of each test object class
            y='filtered_acc', 
            hue='condition',
            palette='magma', 
            ax=ax1, 
            size=3.5, 
            edgecolor='black', 
            linewidth= 1.5, 
            marker='o',
            alpha = 0.75,
            jitter=True,  # Add jitter to avoid overlapping points
        )
    elif extreme == True:
        sns.pointplot(
            data=data,
            x="stimulus_duration",
            y="filtered_acc",
            hue="condition",
            palette="magma",
            order=[0.3, 0.136, 0.068, 0.034],
            capsize=0.2,
            errorbar= ("ci", 95)
        )
    
    ax1.set_ylim(0, 1.0)
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Condition')
    ax1.axhline(y=chance, color='black', linestyle='--', linewidth=1.5, zorder=11)
    return plt.gca()

# %% [markdown]
# # Run the Preprocessing and Exclusion Functions

# %% [markdown]
# ## Mini-Glint

# %% [markdown]
# ### Group by image class and condition

# %%
#Clear previous output and variables to ensure no mixing of the data
# %reset -f

# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb

def mini_glint_preprocessing_pipeline(experiment, mini=True):

    settings = {'experiment': experiment, 'mini': mini }
    
    experiment = settings['experiment'] #version of the experiment: novel only

    mini = settings['mini'] # Sets mini flag to check if this is the mini version of the experiment or not

    animacy = 'inanim_artificial'

    img_classes = ['krar', 'sistrum', 'sarangi', 'sheng']


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                'test_object_class', #test object class 
                'practice_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'number_of_no_responses', #number of no responses
                'number_of_fast_responses', #number of fast responses (RT < 100ms)
                'pre_filter_trial_count', #number of trials before any exclusions
                'final_trial_count', #number of trials after all exclusions
                'number_of_outliers', #number of RT outliers
                'number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses)
    

    #Create an empty dataframe to hold the summary data for all subjects and conditions, this will be populated in the loop through the files
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data

    #Mini should equal True, if false you are using wrong pipeline
    if mini == True:
        base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
        core_path = f'{base}/mini_glint/shape' #default core path for mini version
    elif mini == False:
        print("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline.")
        raise ValueError("Mini flag is set to False, but this pipeline is only designed for the mini version of the experiment. Please set mini=True to run this pipeline.")

    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
        except Exception as e:
            print(f"Failed to read {file}: {e}")
            raise ValueError("No file by this name.")
        
        # Check if the 'participant' column is in the data, if not, print an error message and raise a ValueError to skip this file and move on to the next one.
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")
            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

        #rename the columns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # If test_condition == 1 then condition is feature, if test_condition == 2 then condition is shape
        if data['test_condition'].iloc[0] == 1:
            conditions = 'feature'
        elif data['test_condition'].iloc[0] == 2:
            conditions = 'shape'
        

        '''
        if you dont want trial level summary of data, then just change img_class to condition like so:
        for condition in conditions:
            and then you can remove the test_object_class from the row dictionary and the base_cols list
        '''
        # Loop through each image class
        for img_class in img_classes:            
            # Check for required columns
            needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition']  #list of needed columns for processing

            # print out the available columns, required columns, and any missing columns for debugging purposes
            print(f"\n  Available columns: {data.columns.tolist()}")
            print(f"  Required columns: {needed}")
            missing_cols = [col for col in needed if col not in data.columns]
            if missing_cols:
                print(f"  MISSING: {missing_cols}")

            if any(col not in data.columns for col in needed): 
                print(f"Missing expected columns in {file}") 
                raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
            
              
            # Use trials function to import trials and filter based on current parameters
            trials = data[(data['test_object_class'] == img_class)]

            #trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]
    
            # Check if trials is None or empty, and will raise an error if so
            if trials is None or len(trials) == 0:
                print(f"  No trials found for {img_class}")
                raise ValueError("No trials found.")

            # Takes only trials with a response, and counts the number of no responses
            no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
            number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses

            '''
            Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
            Exclusion Criteria 2: RTs outside mean ± 2*SD
            We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
            and then we apply the RT filters to those trials. This way we can accurately count 
            the number of no responses, fast responses, and RT outliers separately.
            '''

            #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
            rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
            number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms

            #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
            #rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
            #mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
            #std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT

            # As we only have for trials we can not apply standard deviation based filtering, so we will skip that step and not filter out any RTs based on the mean ± 2*SD criterion, and we will set the number of outliers to 0 for this case
            final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion

            # Calculate the number of no responses and fast responses that were excluded based on the filters applied
            number_of_excluded_trials = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers

            # Calculate total number of trials for this subject
            total_trials = len(final_trials) #total number of trials for this subject and condition before any exclusions

            #Calculate the filtered accuracy after applying the response and RT filters
            filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   

            #Combines the experiment and extreme parameters into a single label for the summary dataframe
            experiment_label = f"mini_{experiment}_glint"  #combine experiment and extreme status into a single label for the summary dataframe    


            #Compiles all the variables of interest into a row for the condition summary dataframe
            row = {
                'experiment_label': experiment_label, #experiment and extreme status
                'id': sub, #subject identifier
                'condition': conditions, #condition (natural, scrambled, line_drawing)
                'stimulus_duration': 0.3, #stimulus duration (only if extreme is True)
                'animacy': animacy, #animacy (only if animacy_inclusion is True)
                'test_object_class': img_class, #test object class (only if test_object_class_inclusion is True)
                'practice_acc': practice_trials, #accuracy in practice trials
                'filtered_acc': filtered_acc, #accuracy after filtering
                'number_of_no_responses': number_of_no_responses, #number of no responses
                'number_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
                'pre_filter_trial_count': len(trials), #number of trials before any exclusions
                'final_trial_count': total_trials, #number of trials after all exclusions
                'number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
            }

            # Add the row to the condition summary
            condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

        # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, mini  # return config so downstream steps use the same values

# Quick Visualization
def plot_summary(data, extreme,chance):
    import seaborn as sns
    import matplotlib.pyplot as plt

    fig, ax1 = plt.subplots(figsize=(8, 5))
    if extreme == False:
        sns.barplot(
            data=data,
            x="condition",
            y="filtered_acc",
            ax = ax1,
            capsize=0.3,
            errorbar=("ci", 95),
            palette="magma",
            zorder=2,
            hue="condition"
        )
        sns.stripplot(
            data, 
            x='condition', #Change to condition if we want to plot individual points for each condition instead of each test object class
            y='filtered_acc', 
            hue='condition',
            palette='magma', 
            ax=ax1, 
            size=3.5, 
            edgecolor='black', 
            linewidth= 1.5, 
            marker='o',
            alpha = 0.75,
            jitter=True,  # Add jitter to avoid overlapping points
        )
    elif extreme == True:
        sns.pointplot(
            data=data,
            x="stimulus_duration",
            y="filtered_acc",
            hue="condition",
            palette="magma",
            order=[0.3, 0.136, 0.068, 0.034],
            capsize=0.2,
            errorbar= ("ci", 95)
        )
    
    ax1.set_ylim(0, 1.0)
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Condition')
    ax1.axhline(y=chance, color='black', linestyle='--', linewidth=1.5, zorder=11)
    return plt.gca()

# %% [markdown]
# ### Group by Condition

# %%
#Clear previous output and variables to ensure no mixing of the data
# %reset -f

# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb


def mini_glint_preprocessing_pipeline(experiment = 'mini'):

    settings = {'experiment': experiment}
    
    experiment = settings['experiment'] #version of the experiment: novel only

    animacy = 'inanim_artificial'

    img_classes = ['krar', 'sistrum', 'sarangi', 'sheng']


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                'practice_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'number_of_no_responses', #number of no responses
                'number_of_fast_responses', #number of fast responses (RT < 100ms)
                'pre_filter_trial_count', #number of trials before any exclusions
                'final_trial_count', #number of trials after all exclusions
                'number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses)

    #Create an empty dataframe to hold the summary data for all subjects and conditions, this will be populated in the loop through the files
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data
    excluded_subjects = [] #initialize empty list to hold the identifiers of any subjects that are excluded based on the practice trial accuracy check


    base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
    core_path = f'{base}/mini_glint' #default core path for mini version

    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
        except Exception as e:
            print(f"Failed to read {file}: {e}")
            raise ValueError("No file by this name.")
        
        # Check if the 'participant' column is in the data, if not, print an error message and raise a ValueError to skip this file and move on to the next one.
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")
            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

        #rename the columns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
                # add sub id to a list of subject that were excluded
                excluded_subjects.append((sub, practice_trials, condition))
                #skip this subject and move on to the next one if practice accuracy is below 0.5, as this indicates potential issues with data quality for this subject
                continue
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # If test_condition == 1 then condition is feature, if test_condition == 2 then condition is shape
        if data['test_condition'].iloc[0] == 1 :
            condition = 'feature'
            print(f"  Condition identified as FEATURE based on 'test_condition' value of {data['test_condition'].iloc[0]}")
        elif data['test_condition'].iloc[0] == 2:
            condition = 'shape'
            print(f"  Condition identified as SHAPE based on 'test_condition' value of {data['test_condition'].iloc[0]}")

        # Check for required columns
        needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition']  #list of needed columns for processing

        # print out the available columns, required columns, and any missing columns for debugging purposes
        print(f"\n  Available columns: {data.columns.tolist()}")
        print(f"  Required columns: {needed}")
        missing_cols = [col for col in needed if col not in data.columns]
        if missing_cols:
            print(f"  MISSING: {missing_cols}")

        if any(col not in data.columns for col in needed): 
            print(f"Missing expected columns in {file}") 
            raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
        
            
        # Use trials function to import trials and filter based on current parameters
        trials = data[(data['condition'] == condition)]

        #trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]

        # Check if trials is None or empty, and will raise an error if so
        if trials is None or len(trials) == 0:
            print(f"  No trials found for {condition}")
            raise ValueError("No trials found.")

        # Takes only trials with a response, and counts the number of no responses
        no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
        number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses

        '''
        Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
        Exclusion Criteria 2: RTs outside mean ± 2*SD
        We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
        and then we apply the RT filters to those trials. This way we can accurately count 
        the number of no responses, fast responses, and RT outliers separately.
        '''

        #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
        rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
        number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms

        #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
        #rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
        #mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
        #std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT

        # As we only have for trials we can not apply standard deviation based filtering, so we will skip that step and not filter out any RTs based on the mean ± 2*SD criterion, and we will set the number of outliers to 0 for this case
        final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion

        # Calculate the number of no responses and fast responses that were excluded based on the filters applied
        number_of_excluded_trials = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers

        # Calculate total number of trials for this subject
        total_trials = len(final_trials) #total number of trials for this subject and condition before any exclusions

        #Calculate the filtered accuracy after applying the response and RT filters
        filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   

        #Combines the experiment and extreme parameters into a single label for the summary dataframe
        experiment_label = f"mini_{experiment}_glint"  #combine experiment and extreme status into a single label for the summary dataframe    


        #Compiles all the variables of interest into a row for the condition summary dataframe
        row = {
            'experiment_label': experiment_label, #experiment and extreme status
            'id': sub, #subject identifier
            'condition': condition, #condition (natural, scrambled, line_drawing)
            'stimulus_duration': 0.3, #stimulus duration (only if extreme is True)
            'animacy': animacy, #animacy (only if animacy_inclusion is True)
            'practice_acc': practice_trials, #accuracy in practice trials
            'filtered_acc': filtered_acc, #accuracy after filtering
            'number_of_no_responses': number_of_no_responses, #number of no responses
            'number_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
            'pre_filter_trial_count': len(trials), #number of trials before any exclusions
            'final_trial_count': total_trials, #number of trials after all exclusions
            'number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
        }

        # Add the row to the condition summary
        condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

    # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, excluded_subjects  # return config so downstream steps use the same values


def create_wide_df_save(cleaned, experiment, output_path):
    cleaned_wide = None
    
    #I kept running into errors when trying to create the wide format, so I wrapped it in a try except block to catch any errors and print them out
    try:
        values = ['condition','filtered_acc', 'practice_acc', 'number_of_no_responses', 'final_trial_count', 'number_of_fast_responses', 'number_of_excluded_trials'] #values to pivot on
        #values = ['un_filtered_acc', 'filtered_acc', 'no_responses', 'num_trials_after_exclusion', 'num_of_outliers', 'num_of_fast_responses', 'total_number_of_excluded_trials'] #values to pivot on

        pivot_df = cleaned.pivot(index='id', columns=[''], values=values) #pivot table with condition, stimulus_duration, and animacy as columns
        
        new_cols = [] #new column names list

        
        for col in pivot_df.columns: #loop through the columns in the pivoted dataframe to format the column names

            if len(col) == 2:
                metric, condition = col #unpack the column tuple into metric, condition, and duration

                new_cols.append(f"{condition}_{metric}") #format new column names

            else:
                new_cols.append("_".join([str(c) for c in col])) #join other columns as strings
        
        pivot_df.columns = new_cols #assign new column names to the pivoted dataframe

        pivot_df.reset_index(inplace=True) #reset index to make 'id' a column again

        cleaned_wide = pivot_df #assign pivoted DataFrame to cleaned_wide

        wide_df = cleaned_wide

        natural_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_natural") and c != "filtered_acc_natural_overall"]
        feature_cols = [c for c in wide_df.columns if c.startswith("filtered_acc_feature") and c != "filtered_acc_feature_overall"]
        shape_cols   = [c for c in wide_df.columns if c.startswith("filtered_acc_shape")   and c != "filtered_acc_shape_overall"]

        natural_accuracy = wide_df[natural_cols].sum(axis=1, skipna=True) / len(natural_cols) if natural_cols else np.nan
        feature_accuracy = wide_df[feature_cols].sum(axis=1, skipna=True) / len(feature_cols) if feature_cols else np.nan
        shape_accuracy   = wide_df[shape_cols].sum(axis=1, skipna=True) / len(shape_cols) if shape_cols else np.nan

        wide_df["filtered_acc_natural_overall"] = natural_accuracy
        wide_df["filtered_acc_feature_overall"] = feature_accuracy
        wide_df["filtered_acc_shape_overall"]   = shape_accuracy

        cleaned_wide = wide_df
        
    except Exception as e:

        cleaned_wide = None #assign None to cleaned_wide if there was an error during pivoting

        print(f"Could not create wide-format: {e}") #alerts you if there was an error in pivoting data

    #Create a name for the final csv files based on the experiment version and extreme flag
    final_csv = f'{experiment}_glint_cleaned.csv' #construct final CSV filename

    #Save the cleaned long-format
    cleaned.to_csv(os.path.join(output_path, final_csv), index=False) #save long-format DataFrame to CSV

    print(f"Final cleaned sub_summary saved to {os.path.join(output_path, final_csv)}") 

    # Save the wide-format DataFrame to CSV, if it was successfully created
    if cleaned_wide is not None:

        

        cleaned_wide.to_csv(os.path.join(output_path, f'{experiment}_glint_cleaned_wide.csv'), index=False) #save wide-format DataFrame to CSV

        print(f"Final cleaned wide-format sub_summary saved to {os.path.join(output_path, f'{experiment}_glint_cleaned_wide.csv')}")

    return cleaned, cleaned_wide


# Quick Visualization
def plot_summary(data, extreme,chance):
    import seaborn as sns
    import matplotlib.pyplot as plt

    fig, ax1 = plt.subplots(figsize=(8, 5))
    if extreme == False:
        sns.barplot(
            data=data,
            x="condition",
            y="filtered_acc",
            ax = ax1,
            capsize=0.3,
            errorbar=("ci", 95),
            palette="magma",
            zorder=2,
            hue="condition"
        )
        sns.stripplot(
            data, 
            x='condition', #Change to condition if we want to plot individual points for each condition instead of each test object class
            y='filtered_acc', 
            hue='condition',
            palette='magma', 
            ax=ax1, 
            size=3.5, 
            edgecolor='black', 
            linewidth= 1.5, 
            marker='o',
            alpha = 0.75,
            jitter=True,  # Add jitter to avoid overlapping points
        )
    elif extreme == True:
        sns.pointplot(
            data=data,
            x="stimulus_duration",
            y="filtered_acc",
            hue="condition",
            palette="magma",
            order=[0.3, 0.136, 0.068, 0.034],
            capsize=0.2,
            errorbar= ("ci", 95)
        )
    
    ax1.set_ylim(0, 1.0)
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Condition')
    ax1.axhline(y=chance, color='black', linestyle='--', linewidth=1.5, zorder=11)
    return plt.gca()

# %%
#Run the preprocessing pipeline for Novel Extreme version, experiment = 'novel' and extreme = True
sub_summary, experiment, excluded_subjects = mini_glint_preprocessing_pipeline(experiment= 'mini')
# Out:
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/388085_mini_novel_glint_2026-05-01_14h44.03.605.csv
#
# Processing Subject: 388085
#   Practice trials accuracy looks good for 388085, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/219659_mini_novel_glint_2026-05-01_10h32.57.823.csv
#
# Processing Subject: 219659
#   Practice trials accuracy looks good for 219659, Accuracy =  0.625
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/631636_mini_novel_glint_2026-05-01_10h32.21.082.csv
#
# Processing Subject: 631636
#   Practice trials accuracy looks good for 631636, Accuracy =  0.812
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/829707_mini_novel_glint_2026-05-01_15h02.25.249.csv
#
# Processing Subject: 829707
#   Practice trials accuracy looks good for 829707, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/343019_mini_novel_glint_2026-05-01_11h33.13.168.csv
#
# Processing Subject: 343019
#   Practice trials accuracy looks good for 343019, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/533226_mini_novel_glint_2026-05-01_10h38.13.652.csv
#
# Processing Subject: 533226
#   Practice trials accuracy looks good for 533226, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/659600_mini_novel_glint_2026-05-05_13h03.52.521.csv
#
# Processing Subject: 659600
#   Practice trials accuracy looks good for 659600, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/525887_mini_novel_glint_2026-05-01_11h32.48.974.csv
#
# Processing Subject: 525887
#   Practice trials accuracy looks good for 525887, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/994752_mini_novel_glint_2026-05-01_14h56.05.652.csv
#
# Processing Subject: 994752
#   Practice trials accuracy looks good for 994752, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/836424_mini_novel_glint_2026-05-05_10h03.50.946.csv
#
# Processing Subject: 836424
#   Practice trials accuracy looks good for 836424, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/435622_mini_novel_glint_2026-05-05_13h04.35.752.csv
#
# Processing Subject: 435622
#   Practice trials accuracy looks good for 435622, Accuracy =  0.750
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/107473_mini_novel_glint_2026-05-01_11h31.58.964.csv
#
# Processing Subject: 107473
#   Practice trials accuracy looks good for 107473, Accuracy =  0.688
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/121691_mini_novel_glint_2026-05-05_13h05.36.604.csv
#
# Processing Subject: 121691
#   Practice trials accuracy looks good for 121691, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/562248_mini_novel_glint_2026-05-05_13h04.41.903.csv
#
# Processing Subject: 562248
#   Practice trials accuracy looks good for 562248, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/125726_mini_novel_glint_2026-05-05_10h03.22.357.csv
#
# Processing Subject: 125726
#   Practice trials accuracy looks good for 125726, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/817958_mini_novel_glint_2026-05-01_10h34.53.078.csv
#
# Processing Subject: 817958
#   Practice trials accuracy looks good for 817958, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/671509_mini_novel_glint_2026-05-01_11h38.30.803.csv
#
# Processing Subject: 671509
#   Practice trials accuracy looks good for 671509, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/231798_mini_novel_glint_2026-05-01_10h34.13.777.csv
#
# Processing Subject: 231798
#   Practice trials accuracy looks good for 231798, Accuracy =  0.938
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/556195_mini_novel_glint_2026-05-01_08h33.30.417.csv
#
# Processing Subject: 556195
#   Practice trials accuracy looks good for 556195, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/049390_mini_novel_glint_2026-05-05_13h10.28.066.csv
#
# Processing Subject: 49390
#   Practice trials accuracy looks good for 49390, Accuracy =  0.875
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/347664_mini_novel_glint_2026-05-01_08h33.43.688.csv
#
# Processing Subject: 347664
#   Practice trials accuracy looks good for 347664, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/710051_mini_novel_glint_2026-05-05_11h09.04.376.csv
#
# Processing Subject: 710051
#   Practice trials accuracy looks good for 710051, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/482030_mini_novel_glint_2026-05-01_14h42.38.322.csv
#
# Processing Subject: 482030
#   Practice trials accuracy looks good for 482030, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/843143_mini_novel_glint_2026-05-25_13h01.50.645.csv
#
# Processing Subject: 843143
#   Practice trials accuracy looks good for 843143, Accuracy =  0.688
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/565315_mini_novel_glint_2026-05-01_14h44.04.968.csv
#
# Processing Subject: 565315
#   Practice trials accuracy looks good for 565315, Accuracy =  0.875
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/764310_mini_novel_glint_2026-05-01_10h33.31.448.csv
#
# Processing Subject: 764310
#   Practice trials accuracy looks good for 764310, Accuracy =  0.938
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/682332_mini_novel_glint_2026-05-05_13h04.08.819.csv
#
# Processing Subject: 682332
#   Practice trials accuracy looks good for 682332, Accuracy =  0.500
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/880030_mini_novel_glint_2026-05-01_11h32.50.103.csv
#
# Processing Subject: 880030
#   Practice trials accuracy looks good for 880030, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/312499_mini_novel_glint_2026-05-05_12h04.19.793.csv
#
# Processing Subject: 312499
#   Practice trials accuracy looks good for 312499, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/124135_mini_novel_glint_2026-05-01_12h56.18.676.csv
#
# Processing Subject: 124135
#   Practice trials accuracy looks good for 124135, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/425794_mini_novel_glint_2026-05-01_14h41.17.439.csv
#
# Processing Subject: 425794
#   Practice trials accuracy looks good for 425794, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/429505_mini_novel_glint_2026-05-25_11h55.02.936.csv
#
# Processing Subject: 429505
#   Practice trials accuracy looks good for 429505, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/274331_mini_novel_glint_2026-05-01_12h45.10.526.csv
#
# Processing Subject: 274331
#   Practice trials accuracy looks good for 274331, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/770571_mini_novel_glint_2026-05-01_14h56.03.946.csv
#
# Processing Subject: 770571
#   Practice trials accuracy looks good for 770571, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/981527_mini_novel_glint_2026-05-01_11h32.44.752.csv
#
# Processing Subject: 981527
#   Practice trials accuracy looks good for 981527, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/486718_mini_novel_glint_2026-05-05_11h04.12.432.csv
#
# Processing Subject: 486718
#   Practice trials accuracy looks good for 486718, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/510364_mini_novel_glint_2026-05-01_11h33.30.281.csv
#
# Processing Subject: 510364
#   Practice trials accuracy looks good for 510364, Accuracy =  0.625
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/503969_mini_novel_glint_2026-05-01_10h37.34.613.csv
#
# Processing Subject: 503969
#   Practice trials accuracy looks good for 503969, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# ...
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/916570_mini_novel_glint_2026-05-25_11h53.16.418.csv
#
# Processing Subject: 916570
#   Practice trials accuracy looks good for 916570, Accuracy =  0.562
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/603731_mini_novel_glint_2026-05-05_10h09.44.743.csv
#
# Processing Subject: 603731
#   Practice trials accuracy looks good for 603731, Accuracy =  0.812
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/688955_mini_novel_glint_2026-05-01_15h50.04.913.csv
#
# Processing Subject: 688955
#   Practice trials accuracy looks good for 688955, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/313391_mini_novel_glint_2026-05-01_15h21.42.516.csv
#
# Processing Subject: 313391
#   Practice trials accuracy looks good for 313391, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/064127_mini_novel_glint_2026-05-05_13h03.44.569.csv
#
# Processing Subject: 64127
#   Practice trials accuracy looks good for 64127, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/007347_mini_novel_glint_2026-05-01_11h33.34.927.csv
#
# Processing Subject: 7347
#   Practice trials accuracy looks good for 7347, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/996454_mini_novel_glint_2026-05-01_11h58.31.527.csv
#
# Processing Subject: 996454
#   Practice trials accuracy looks good for 996454, Accuracy =  0.500
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/653656_mini_novel_glint_2026-05-01_11h32.00.428.csv
#
# Processing Subject: 653656
#   Practice trials accuracy looks good for 653656, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/265573_mini_novel_glint_2026-05-01_15h07.52.549.csv
#
# Processing Subject: 265573
#   Practice trials accuracy looks good for 265573, Accuracy =  0.938
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/168231_mini_novel_glint_2026-05-01_07h34.02.451.csv
#
# Processing Subject: 168231
#   Practice trials accuracy looks good for 168231, Accuracy =  0.688
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/443869_mini_novel_glint_2026-05-01_11h32.29.964.csv
#
# Processing Subject: 443869
#   Practice trials accuracy looks good for 443869, Accuracy =  1.000
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'key_resp.rt', 'key_resp.duration', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/333188_mini_novel_glint_2026-05-05_13h07.10.248.csv
#
# Processing Subject: 333188
#   Practice trials accuracy looks good for 333188, Accuracy =  1.000
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
#   Available columns: ['participant', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'PROLIFIC_PID', 'STUDY_ID', 'SESSION_ID', 'test_condition', 'CorrectResponse', 'prac_img_class', 'prac_prompt_1', 'prac_prompt_2', 'prac_prompt_3', 'prac_prompt_4', 'prac_key_resp.keys', 'prac_key_resp.corr', 'prac_key_resp.rt', 'prac_key_resp.duration', 'prac_response_label', 'practice_trials.thisRepN', 'practice_trials.thisTrialN', 'practice_trials.thisN', 'practice_trials.thisIndex', 'practice_trials.ran', 'filler_name', 'animacy', 'target_img_path', 'corr_ans', 'test_object_class', 'prompt_1', 'prompt_2', 'prompt_3', 'prompt_4', 'condition', 'stim.started', 'stim.stopped', 'key_resp.keys', 'key_resp.corr', 'response_label', 'test_loop.thisRepN', 'test_loop.thisTrialN', 'test_loop.thisN', 'test_loop.thisIndex', 'test_loop.ran', 'key_resp.rt', 'key_resp.duration']
#   Required columns: ['key_resp.corr', 'response_label', 'test_object_class', 'animacy', 'condition']

# %%
#Run the Exclusion Check, remove the flagged subjects, create the wide format, and save the cleaned dataframes to CSV files for the novel original version, experiment = 'novel' and extreme = False
cleaned = sub_summary #make a copy of sub_summary to work with for the exclusion check and removal
create_wide_df_save(cleaned, experiment, output_path= '/zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/')
plot_summary(sub_summary, extreme=False, chance=0.25)
# Out:
# Could not create wide-format: ''
# Final cleaned sub_summary saved to /zpool/vladlab/data_drive/glint_master/data/adult_data/summary_data_csv/mini_glint_cleaned.csv
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %%
# exclude participants who have less than 2 trials 
sub_summary_filtered = sub_summary[sub_summary['final_trial_count'] >= 2]
plot_summary(sub_summary_filtered, extreme= False, chance=0.25)
# Out:
# <Axes: xlabel='Condition', ylabel='Accuracy'>

# %%
# Calculate the number of subjects that were excluded based on the practice accuracy check and the trial count check
num_excluded_practice = len(excluded_subjects)
#num_excluded_trial_count = len(sub_summary) - len(sub_summary_filtered)
print(f"Number of subjects excluded based on practice accuracy check: {num_excluded_practice}")
#print(f"Number of subjects excluded based on trial count check: {num_excluded_trial_count}")
# Out:
# Number of subjects excluded based on practice accuracy check: 0

# %%
# count number of shape and feature subjects
num_shape_subjects = sub_summary[sub_summary['condition'] == 'shape']['id'].nunique()
num_feature_subjects = sub_summary[sub_summary['condition'] == 'feature']['id'].nunique()
print(f"Number of unique subjects in shape condition: {num_shape_subjects}")
print(f"Number of unique subjects in feature condition: {num_feature_subjects}")
# Out:
# Number of unique subjects in shape condition: 47
# Number of unique subjects in feature condition: 50

# %% [markdown]
# # Only use first trial to determine accuracy

# %%
# Import Necessary Packages 
import os
import pandas as pd
import glob
import numpy as np
import pdb


def mini_glint_preprocessing_pipeline(experiment = 'mini'):

    settings = {'experiment': experiment}
    
    experiment = settings['experiment'] #version of the experiment: novel only

    animacy = 'inanim_artificial'

    img_classes = ['krar', 'sistrum', 'sarangi', 'sheng']


    # Define the columns for the summary dataframe, this will be used to compile the results for each subject and condition
    base_cols = ['experiment_label', 
                'id', #subject identifier
                'condition', #condition (natural, feature, shape)
                'stimulus_duration',#stimulus duration (only if extreme is True)
                'animacy', #animacy (only if animacy_inclusion is True)
                'practice_acc', #accuracy before filtering
                'filtered_acc', #accuracy after filtering
                'number_of_no_responses', #number of no responses
                'number_of_fast_responses', #number of fast responses (RT < 100ms)
                'pre_filter_trial_count', #number of trials before any exclusions
                'final_trial_count', #number of trials after all exclusions
                'number_of_excluded_trials'] #total number of excluded trials (no responses + fast responses)

    #Create an empty dataframe to hold the summary data for all subjects and conditions, this will be populated in the loop through the files
    sub_summary = pd.DataFrame(columns=base_cols) #initialize empty dataframe with the appropriate columns, this will hold the final summary data
    excluded_subjects = [] #initialize empty list to hold the identifiers of any subjects that are excluded based on the practice trial accuracy check


    base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
    core_path = f'{base}/mini_glint' #default core path for mini version

    #Now that they have selected the path for this version, it will gather all files associated with that version of the experiment    
    files = glob.glob(f'{core_path}/*.csv')  


    # Loop through each subject in this version of the experiment and process their data
    for file in files:
        print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
        try:
            predata = pd.read_csv(file) #read in the data file

        # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
        except Exception as e:
            print(f"Failed to read {file}: {e}")
            raise ValueError("No file by this name.")
        
        # Check if the 'participant' column is in the data, if not, print an error message and raise a ValueError to skip this file and move on to the next one.
        if 'participant' not in predata.columns:
            print(f"Error detected, 'participant' column missing in {file}")
            raise ValueError("Missing 'participant' column in data.") #Acts as a first layer defense to catch files that may not have the expected structure
        
        
        #Define a mapping of the data columns to standardize the column names across versions of the experiment 
        column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

        #rename the columns to standardize across experiment versions
        data = predata.rename(columns=column_map)

        # Define a mapping for the conditions to standardize the condition names to their true names
        condition_mapping = {"natural": "natural", "scrambled": "feature", "line_drawing": "shape"}
        
        #Standardize the condition names in the data using the mapping
        data["condition"] = data["condition"].replace(condition_mapping)

        #get subject identifier from the data
        sub = data.loc[0, 'participant']
        print(f"\nProcessing Subject: {data.loc[0, 'participant']}")

        #initialize empty dataframe for this subject's conditions to hold the summary data for each loop through the conditions, stimulus durations, and animacies
        condition_summary = pd.DataFrame(columns=sub_summary.columns)
        
        # Check practice accuracy if column exists
        if 'prac_key_resp.corr' in data.columns:
            practice_trials = data['prac_key_resp.corr'].mean() #calculate practice trials accuracy
            #print(f"  Practice trials accuracy: {practice_trials:.3f}")
            if practice_trials < 0.5:
                print(f"  Caution: Low accuracy in practice trials for {data.loc[0, 'participant']} Accuracy =  {practice_trials:.3f}. Check data quality.")
                # add sub id to a list of subject that were excluded
                excluded_subjects.append((sub, practice_trials, condition))
                #skip this subject and move on to the next one if practice accuracy is below 0.5, as this indicates potential issues with data quality for this subject
                continue
            elif practice_trials >= 0.5:
                print(f"  Practice trials accuracy looks good for {data.loc[0, 'participant']}, Accuracy =  {practice_trials:.3f}")
        else:
            print(f"  Warning: 'prac_key_resp.corr' column not found in {file}")
        # If test_condition == 1 then condition is feature, if test_condition == 2 then condition is shape
        if data['test_condition'].iloc[0] == 1 :
            condition = 'feature'
            print(f"  Condition identified as FEATURE based on 'test_condition' value of {data['test_condition'].iloc[0]}")
        elif data['test_condition'].iloc[0] == 2:
            condition = 'shape'
            print(f"  Condition identified as SHAPE based on 'test_condition' value of {data['test_condition'].iloc[0]}")

        # Check for required columns
        needed = ['key_resp.corr', 'response_label','test_object_class','animacy','condition']  #list of needed columns for processing

        # print out the available columns, required columns, and any missing columns for debugging purposes
        print(f"\n  Available columns: {data.columns.tolist()}")
        print(f"  Required columns: {needed}")
        missing_cols = [col for col in needed if col not in data.columns]
        if missing_cols:
            print(f"  MISSING: {missing_cols}")

        if any(col not in data.columns for col in needed): 
            print(f"Missing expected columns in {file}") 
            raise ValueError("Missing expected columns in data.") #Second layer of defense to catch files that may be missing critical columns for the analysis
        
            
        # Use trials function to import trials and filter based on current parameters
        trials = data[(data['condition'] == condition)]

        #trials = data[(data['condition'] == condition) & (data['animacy'] == animacy)]

        # Check if trials is None or empty, and will raise an error if so
        if trials is None or len(trials) == 0:
            print(f"  No trials found for {condition}")
            raise ValueError("No trials found.")

        # Takes only trials with a response, and counts the number of no responses
        no_response_filter = trials[trials['response_label'] != 'no response'] #filter out no responses
        number_of_no_responses = len(trials) - len(no_response_filter) #count number of no responses

        '''
        Exclusion Criteria 1: RTs less than or equal to 100ms, and counts the number of fast responses
        Exclusion Criteria 2: RTs outside mean ± 2*SD
        We also remove no responses first, so that we are only looking at RTs for trials where there was a response, 
        and then we apply the RT filters to those trials. This way we can accurately count 
        the number of no responses, fast responses, and RT outliers separately.
        '''

        #Filters out RTs less than or equal to 100ms, and counts the number of fast responses
        rt_less_equal_100 = no_response_filter[no_response_filter['key_resp.rt'] >= 0.100] #filter out RTs less than or equal to 100ms
        number_of_fast_responses = len(no_response_filter) - len(rt_less_equal_100) #count number of RTs less than or equal to 100ms

        #Calculates the mean and standard deviation of RTs for trials with RTs greater than 100ms, which will be used to identify outliers based on the mean ± 2*SD criterion
        #rt_plus_minus_2sd = rt_less_equal_100['key_resp.rt'].dropna() #drop NaN values
        #mean_rt = rt_plus_minus_2sd.mean() #calculate mean RT
        #std_rt = rt_plus_minus_2sd.std(ddof=1) #calculate standard deviation of RT

        # As we only have for trials we can not apply standard deviation based filtering, so we will skip that step and not filter out any RTs based on the mean ± 2*SD criterion, and we will set the number of outliers to 0 for this case
        final_trials = rt_less_equal_100 #if we cannot calculate a standard deviation, we will not filter out any RTs based on the mean ± 2*SD criterion

        # Calculate the number of no responses and fast responses that were excluded based on the filters applied
        number_of_excluded_trials = len(rt_less_equal_100) - len(final_trials) #count number of RT outliers

        # Calculate total number of trials for this subject
        total_trials = len(final_trials) #total number of trials for this subject and condition before any exclusions

        #Calculate the filtered accuracy after applying the response and RT filters
        filtered_acc = final_trials['key_resp.corr'].mean() #accuracy after filtering   

        #Combines the experiment and extreme parameters into a single label for the summary dataframe
        experiment_label = f"mini_{experiment}_glint"  #combine experiment and extreme status into a single label for the summary dataframe    


        #Compiles all the variables of interest into a row for the condition summary dataframe
        row = {
            'experiment_label': experiment_label, #experiment and extreme status
            'id': sub, #subject identifier
            'condition': condition, #condition (natural, scrambled, line_drawing)
            'stimulus_duration': 0.3, #stimulus duration (only if extreme is True)
            'animacy': animacy, #animacy (only if animacy_inclusion is True)
            'practice_acc': practice_trials, #accuracy in practice trials
            'filtered_acc': filtered_acc, #accuracy after filtering
            'number_of_no_responses': number_of_no_responses, #number of no responses
            'number_of_fast_responses': number_of_fast_responses, #number of fast responses (RT < 100ms)
            'pre_filter_trial_count': len(trials), #number of trials before any exclusions
            'final_trial_count': total_trials, #number of trials after all exclusions
            'number_of_excluded_trials': number_of_excluded_trials, #total number of excluded trials
        }

        # Add the row to the condition summary
        condition_summary = pd.concat([condition_summary, pd.DataFrame([row])], ignore_index=True) #append the row to the condition summary

    # After processing all conditions for this subject, append to the overall sub_summary
        sub_summary = pd.concat([sub_summary, condition_summary], ignore_index=True) #append the condition summary to the overall sub_summary


    return sub_summary, experiment, excluded_subjects  # return config so downstream steps use the same values

# %%
import os
import pandas as pd
import glob
import numpy as np
import pdb

base = '/zpool/vladlab/data_drive/glint_master/data/adult_data' #base path for the data, this is the same for all versions of the experiment
core_path = f'{base}/mini_glint' #default core path for mini version

files = glob.glob(f'{core_path}/*.csv')
print(files)

for file in files:
    print(f"\nProcessing file: {file}") #print the file being processed for tracking purposes
    try:
        predata = pd.read_csv(file) #read in the data file

    # If there is an error reading the file, print the error and raise a ValueError to skip this file and move on to the next one
    except Exception as e:
        print(f"Failed to read {file}: {e}")
        raise ValueError("No file by this name.")
    
    # Define mapping of the data columns
    column_map = {
        "img_condition": "condition",
        "object_category": "animacy",
        "img_class": "test_object_class",
        "object_class": "test_object_class"}

    #rename the columns to standardize across experiment versions
    data = predata.rename(columns=column_map)
    
    # Determine condition based on 'test_condition' value, if test_condition == 1 
    # then condition is feature, if test_condition == 2 then condition is shape
    if data['test_condition'].iloc[0] == 1 :
        condition = 'feature'
        print(f"  Condition identified as FEATURE based on 'test_condition' value of {data['test_condition'].iloc[0]}")
    elif data['test_condition'].iloc[0] == 2:
        condition = 'shape'
        print(f"  Condition identified as SHAPE based on 'test_condition' value of {data['test_condition'].iloc[0]}")

    #Filter by condition 
    trials = data[(data['condition'] == condition)]
    first_trial = data.groupby('condition', sort=False).head(1)
# Out:
# ['/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/388085_mini_novel_glint_2026-05-01_14h44.03.605.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/219659_mini_novel_glint_2026-05-01_10h32.57.823.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/631636_mini_novel_glint_2026-05-01_10h32.21.082.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/829707_mini_novel_glint_2026-05-01_15h02.25.249.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/343019_mini_novel_glint_2026-05-01_11h33.13.168.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/533226_mini_novel_glint_2026-05-01_10h38.13.652.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/659600_mini_novel_glint_2026-05-05_13h03.52.521.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/525887_mini_novel_glint_2026-05-01_11h32.48.974.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/994752_mini_novel_glint_2026-05-01_14h56.05.652.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/836424_mini_novel_glint_2026-05-05_10h03.50.946.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/435622_mini_novel_glint_2026-05-05_13h04.35.752.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/107473_mini_novel_glint_2026-05-01_11h31.58.964.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/121691_mini_novel_glint_2026-05-05_13h05.36.604.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/562248_mini_novel_glint_2026-05-05_13h04.41.903.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/125726_mini_novel_glint_2026-05-05_10h03.22.357.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/817958_mini_novel_glint_2026-05-01_10h34.53.078.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/671509_mini_novel_glint_2026-05-01_11h38.30.803.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/231798_mini_novel_glint_2026-05-01_10h34.13.777.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/556195_mini_novel_glint_2026-05-01_08h33.30.417.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/049390_mini_novel_glint_2026-05-05_13h10.28.066.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/347664_mini_novel_glint_2026-05-01_08h33.43.688.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/710051_mini_novel_glint_2026-05-05_11h09.04.376.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/482030_mini_novel_glint_2026-05-01_14h42.38.322.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/843143_mini_novel_glint_2026-05-25_13h01.50.645.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/565315_mini_novel_glint_2026-05-01_14h44.04.968.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/764310_mini_novel_glint_2026-05-01_10h33.31.448.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/682332_mini_novel_glint_2026-05-05_13h04.08.819.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/880030_mini_novel_glint_2026-05-01_11h32.50.103.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/312499_mini_novel_glint_2026-05-05_12h04.19.793.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/124135_mini_novel_glint_2026-05-01_12h56.18.676.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/425794_mini_novel_glint_2026-05-01_14h41.17.439.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/429505_mini_novel_glint_2026-05-25_11h55.02.936.csv', '/zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/274331_mini_novel_glint_2026-05-01_12h45.10.526.csv', '/zpoo ...
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/388085_mini_novel_glint_2026-05-01_14h44.03.605.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/219659_mini_novel_glint_2026-05-01_10h32.57.823.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/631636_mini_novel_glint_2026-05-01_10h32.21.082.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/829707_mini_novel_glint_2026-05-01_15h02.25.249.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/343019_mini_novel_glint_2026-05-01_11h33.13.168.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/533226_mini_novel_glint_2026-05-01_10h38.13.652.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/659600_mini_novel_glint_2026-05-05_13h03.52.521.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/525887_mini_novel_glint_2026-05-01_11h32.48.974.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/994752_mini_novel_glint_2026-05-01_14h56.05.652.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/836424_mini_novel_glint_2026-05-05_10h03.50.946.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/435622_mini_novel_glint_2026-05-05_13h04.35.752.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/107473_mini_novel_glint_2026-05-01_11h31.58.964.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/121691_mini_novel_glint_2026-05-05_13h05.36.604.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/562248_mini_novel_glint_2026-05-05_13h04.41.903.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/125726_mini_novel_glint_2026-05-05_10h03.22.357.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/817958_mini_novel_glint_2026-05-01_10h34.53.078.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/671509_mini_novel_glint_2026-05-01_11h38.30.803.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/231798_mini_novel_glint_2026-05-01_10h34.13.777.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/556195_mini_novel_glint_2026-05-01_08h33.30.417.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/049390_mini_novel_glint_2026-05-05_13h10.28.066.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/347664_mini_novel_glint_2026-05-01_08h33.43.688.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/710051_mini_novel_glint_2026-05-05_11h09.04.376.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/482030_mini_novel_glint_2026-05-01_14h42.38.322.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/843143_mini_novel_glint_2026-05-25_13h01.50.645.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/565315_mini_novel_glint_2026-05-01_14h44.04.968.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/764310_mini_novel_glint_2026-05-01_10h33.31.448.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/682332_mini_novel_glint_2026-05-05_13h04.08.819.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/880030_mini_novel_glint_2026-05-01_11h32.50.103.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/312499_mini_novel_glint_2026-05-05_12h04.19.793.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/124135_mini_novel_glint_2026-05-01_12h56.18.676.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/425794_mini_novel_glint_2026-05-01_14h41.17.439.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/429505_mini_novel_glint_2026-05-25_11h55.02.936.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/274331_mini_novel_glint_2026-05-01_12h45.10.526.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/770571_mini_novel_glint_2026-05-01_14h56.03.946.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/981527_mini_novel_glint_2026-05-01_11h32.44.752.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/486718_mini_novel_glint_2026-05-05_11h04.12.432.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/510364_mini_novel_glint_2026-05-01_11h33.30.281.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/503969_mini_novel_glint_2026-05-01_10h37.34.613.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/129530_mini_novel_glint_2026-05-01_15h23.02.821.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/340344_mini_novel_glint_2026-05-01_11h33.03.072.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/560572_mini_novel_glint_2026-05-01_11h33.05.347.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/438714_mini_novel_glint_2026-05-01_15h20.57.609.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/507954_mini_novel_glint_2026-05-01_10h37.17.379.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/520539_mini_novel_glint_2026-05-01_15h31.04.236.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/807887_mini_novel_glint_2026-05-01_14h54.42.660.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/404436_mini_novel_glint_2026-05-01_13h55.03.561.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/143779_mini_novel_glint_2026-05-01_10h33.19.672.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/101076_mini_novel_glint_2026-05-01_11h33.17.305.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/023485_mini_novel_glint_2026-05-05_13h04.37.413.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/714825_mini_novel_glint_2026-05-01_10h34.26.941.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/764804_mini_novel_glint_2026-05-01_11h36.23.949.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/848830_mini_novel_glint_2026-05-01_15h40.06.178.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/320861_mini_novel_glint_2026-05-25_11h54.44.390.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/833808_mini_novel_glint_2026-05-25_10h54.04.095.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/199496_mini_novel_glint_2026-05-01_08h31.58.210.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/440878_mini_novel_glint_2026-05-01_10h32.20.733.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/502747_mini_novel_glint_2026-05-01_14h19.21.775.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/663635_mini_novel_glint_2026-05-01_14h19.51.170.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/371576_mini_novel_glint_2026-05-01_08h33.27.337.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/642289_mini_novel_glint_2026-05-01_11h37.40.458.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/590213_mini_novel_glint_2026-05-01_10h33.26.634.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/818893_mini_novel_glint_2026-05-05_10h07.17.353.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/082163_mini_novel_glint_2026-05-05_13h07.13.870.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/602498_mini_novel_glint_2026-05-01_11h37.03.295.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/670038_mini_novel_glint_2026-05-01_10h31.56.120.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/695070_mini_novel_glint_2026-05-01_15h13.28.537.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/587479_mini_novel_glint_2026-05-01_11h38.55.610.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/457910_mini_novel_glint_2026-05-01_11h37.15.704.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/435684_mini_novel_glint_2026-05-05_13h04.25.056.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/141557_mini_novel_glint_2026-05-01_10h33.21.313.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/622454_mini_novel_glint_2026-05-01_14h44.36.100.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/845632_mini_novel_glint_2026-05-01_11h33.21.174.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/725590_mini_novel_glint_2026-05-01_10h33.54.802.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/569166_mini_novel_glint_2026-05-01_09h32.29.051.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/739306_mini_novel_glint_2026-05-05_13h04.38.499.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/285232_mini_novel_glint_2026-05-05_13h03.15.441.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/994334_mini_novel_glint_2026-05-05_13h31.56.008.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/627978_mini_novel_glint_2026-05-05_13h05.56.880.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/063829_mini_novel_glint_2026-05-01_09h33.23.967.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/197602_mini_novel_glint_2026-05-01_08h32.02.390.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/631802_mini_novel_glint_2026-05-01_13h42.36.773.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/618494_mini_novel_glint_2026-05-01_14h06.38.975.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/499209_mini_novel_glint_2026-05-01_11h33.57.324.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/816005_mini_novel_glint_2026-05-01_12h21.34.812.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/938088_mini_novel_glint_2026-05-01_10h41.13.139.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/761467_mini_novel_glint_2026-05-05_13h35.52.905.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/764280_mini_novel_glint_2026-05-01_13h57.21.416.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/049158_mini_novel_glint_2026-05-01_14h56.19.121.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/916570_mini_novel_glint_2026-05-25_11h53.16.418.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/603731_mini_novel_glint_2026-05-05_10h09.44.743.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/688955_mini_novel_glint_2026-05-01_15h50.04.913.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/313391_mini_novel_glint_2026-05-01_15h21.42.516.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/064127_mini_novel_glint_2026-05-05_13h03.44.569.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/007347_mini_novel_glint_2026-05-01_11h33.34.927.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/996454_mini_novel_glint_2026-05-01_11h58.31.527.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/653656_mini_novel_glint_2026-05-01_11h32.00.428.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/265573_mini_novel_glint_2026-05-01_15h07.52.549.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/168231_mini_novel_glint_2026-05-01_07h34.02.451.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/443869_mini_novel_glint_2026-05-01_11h32.29.964.csv
#   Condition identified as FEATURE based on 'test_condition' value of 1
#
# Processing file: /zpool/vladlab/data_drive/glint_master/data/adult_data/mini_glint/333188_mini_novel_glint_2026-05-05_13h07.10.248.csv
#   Condition identified as SHAPE based on 'test_condition' value of 2
